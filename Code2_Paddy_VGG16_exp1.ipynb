# %% [markdown]
# <a href="https://colab.research.google.com/github/anikch/paddy/blob/main/Code2_Paddy_VGG16_exp1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow_addons
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflow_addons in /usr/local/lib/python3.7/dist-packages (0.18.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tensorflow_addons) (21.3)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow_addons) (2.7.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tensorflow_addons) (3.0.9)

# %%
# !pip install keras_cv
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: keras_cv in /usr/local/lib/python3.7/dist-packages (0.3.4)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.7/dist-packages (from keras_cv) (1.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from keras_cv) (21.3)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from keras_cv) (2022.6.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->keras_cv) (3.0.9)

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import tensorflow_addons as tfa
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import seaborn as sns
from typing import List
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from functools import partial
import posixpath
from keras import models, regularizers, layers, optimizers, losses, metrics
import keras_cv
from keras.models import Sequential
from keras.layers import Dense
from tensorflow.keras.utils import plot_model

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !nvidia-smi
# Out:
# Mon Oct 24 16:56:15 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  A100-SXM4-40GB      Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    47W / 400W |      0MiB / 40536MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
colab= '/content/drive/MyDrive'
local= r'G:\My Drive'

code_runtime= colab

# %%
tf.__version__
# Out:
# '2.9.2'

# %%
file1= 'thesis/dataset/paddy_doctor/train.csv'
inp_file = posixpath.join(code_runtime, file1)

train_table=pd.read_csv(inp_file)
train_table
# Out:
#          image_id                  label variety  age
# 0      100330.jpg  bacterial_leaf_blight   ADT45   45
# 1      100365.jpg  bacterial_leaf_blight   ADT45   45
# 2      100382.jpg  bacterial_leaf_blight   ADT45   45
# 3      100632.jpg  bacterial_leaf_blight   ADT45   45
# 4      101918.jpg  bacterial_leaf_blight   ADT45   45
# ...           ...                    ...     ...  ...
# 10402  107607.jpg                 tungro   Zonal   55
# 10403  107811.jpg                 tungro   Zonal   55
# 10404  108547.jpg                 tungro   Zonal   55
# 10405  110245.jpg                 tungro   Zonal   55
# 10406  110381.jpg                 tungro   Zonal   55
#
# [10407 rows x 4 columns]

# %%
labels=list(np.unique(train_table['label']))
labels
# Out:
# ['bacterial_leaf_blight',
#  'bacterial_leaf_streak',
#  'bacterial_panicle_blight',
#  'blast',
#  'brown_spot',
#  'dead_heart',
#  'downy_mildew',
#  'hispa',
#  'normal',
#  'tungro']

# %%
train_dir= 'thesis/dataset/paddy_doctor/train/'
val_dir= 'thesis/dataset/paddy_doctor/val/'
img_size= 224

train_files= posixpath.join(code_runtime, train_dir)
test_files= posixpath.join(code_runtime, val_dir)

train_data= tf.keras.utils.image_dataset_from_directory(train_files,
                                                        labels='inferred',
                                                        label_mode='categorical',
                                                        validation_split=0.2,
                                                        subset="training",
                                                        class_names=labels,
                                                        color_mode='rgb',
                                                        image_size=(img_size, img_size),
                                                        shuffle=True,
                                                        seed= 42,
                                                        batch_size= 16)

val_data= tf.keras.utils.image_dataset_from_directory(train_files,
                                                        labels= 'inferred',
                                                        label_mode='categorical',
                                                        validation_split=0.2,
                                                        subset="validation",
                                                        class_names= labels,
                                                        color_mode='rgb',
                                                        image_size=(img_size, img_size),
                                                        shuffle=True,
                                                        seed= 42,
                                                        batch_size= 16)


test_datagen= ImageDataGenerator()
test_data= test_datagen.flow_from_directory(test_files,
                                            target_size= (img_size, img_size),
                                            batch_size= 16,
                                            shuffle = False, 
                                            class_mode='categorical')
# Out:
# Found 14302 files belonging to 10 classes.
# Using 11442 files for training.
# Found 14302 files belonging to 10 classes.
# Using 2860 files for validation.
# Found 1500 images belonging to 10 classes.

# %%
class_names = train_data.class_names
print(class_names)
# Out:
# ['bacterial_leaf_blight', 'bacterial_leaf_streak', 'bacterial_panicle_blight', 'blast', 'brown_spot', 'dead_heart', 'downy_mildew', 'hispa', 'normal', 'tungro']

# %%
test_data.class_indices
# Out:
# {'bacterial_leaf_blight': 0,
#  'bacterial_leaf_streak': 1,
#  'bacterial_panicle_blight': 2,
#  'blast': 3,
#  'brown_spot': 4,
#  'dead_heart': 5,
#  'downy_mildew': 6,
#  'hispa': 7,
#  'normal': 8,
#  'tungro': 9}

# %%
optimizer_adam_amsgrad= tf.keras.optimizers.Adam(learning_rate= 1e-4, amsgrad= True)
optimizer_adam= tf.keras.optimizers.Adam(learning_rate= 1e-4, amsgrad= False)
optimizer_sgd= tf.keras.optimizers.SGD(lr=1e-4, momentum= 0.9)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizers/optimizer_v2/gradient_descent.py:108: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)

# %% [markdown]
# ## 1. VGG16 (No Augmentation + Training from scratch)

# %%
base_model= tf.keras.applications.VGG16(
    include_top= False,
    weights= None,
    input_shape=(img_size, img_size, 3),
    pooling= 'max'
)

# %%
tf.keras.utils.plot_model(
    base_model,
    show_shapes= True,
    show_dtype=False,
    show_layer_names=True,
    rankdir="TR",
    expand_nested=False,
    dpi=72,
    layer_range=None,
    show_layer_activations=True,
)

# %%
inputs= tf.keras.Input(shape= (img_size, img_size, 3))
preprocess_layer= tf.keras.applications.vgg16.preprocess_input(inputs)
normalization_layer= tf.keras.layers.Rescaling(scale= 1./127.5, offset= -1)(preprocess_layer)
x= base_model(normalization_layer)
x= tf.keras.layers.Dropout(0.25)(x)
outputs= tf.keras.layers.Dense(10, activation= 'softmax')(x)

# %%
model= tf.keras.Model(inputs= inputs, outputs= outputs, name= "vgg16_scratch_no_augmentation")

# %%
model.summary()
# Out:
# Model: "vgg16_scratch_no_augmentation"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem (S  (None, 224, 224, 3)      0
#  licingOpLambda)
#
#  tf.nn.bias_add (TFOpLambda)  (None, 224, 224, 3)      0
#
#  rescaling (Rescaling)       (None, 224, 224, 3)       0
#
#  vgg16 (Functional)          (None, 512)               14714688
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense (Dense)               (None, 10)                5130
#
# =================================================================
# Total params: 14,719,818
# Trainable params: 14,719,818
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(
    model,
    show_shapes= True,
    show_dtype=False,
    show_layer_names=True,
    rankdir="TR",
    expand_nested=False,
    dpi=72,
    layer_range=None,
    show_layer_activations=True,
)

# %%
# %%time
n_epochs= 100

filepath= "weights-improvement-{epoch:02d}-{val_accuracy:.4f}.hdf5"
checkpoint_callback= ModelCheckpoint(filepath, monitor= 'val_accuracy', verbose= 1, save_best_only= True, mode= 'max')
early_stop_callback= EarlyStopping(monitor='val_accuracy', patience= 5, verbose= False, mode='max')
callbacks_list=[checkpoint_callback, early_stop_callback]
# Out:
# CPU times: user 103 µs, sys: 54 µs, total: 157 µs
# Wall time: 163 µs

# %%
model.compile(
        optimizer = optimizer_sgd,
        loss = 'categorical_crossentropy', 
        metrics = ['accuracy', tfa.metrics.F1Score(average='macro', num_classes= 10)]
        )

# %%
history= model.fit(train_data,
                    epochs= n_epochs,
                    validation_data= val_data,
                    verbose= 1)
# Out:
# Epoch 1/100
# 716/716 [==============================] - 37s 44ms/step - loss: 2.3019 - accuracy: 0.1106 - f1_score: 0.0505 - val_loss: 2.3011 - val_accuracy: 0.1143 - val_f1_score: 0.0205
# Epoch 2/100
# 716/716 [==============================] - 30s 42ms/step - loss: 2.3008 - accuracy: 0.1120 - f1_score: 0.0356 - val_loss: 2.3003 - val_accuracy: 0.1143 - val_f1_score: 0.0205
# Epoch 3/100
# 716/716 [==============================] - 30s 42ms/step - loss: 2.3002 - accuracy: 0.1118 - f1_score: 0.0348 - val_loss: 2.2998 - val_accuracy: 0.1143 - val_f1_score: 0.0205
# Epoch 4/100
# 716/716 [==============================] - 30s 42ms/step - loss: 2.2997 - accuracy: 0.1179 - f1_score: 0.0378 - val_loss: 2.2993 - val_accuracy: 0.1143 - val_f1_score: 0.0205
# Epoch 5/100
# 716/716 [==============================] - 30s 42ms/step - loss: 2.2994 - accuracy: 0.1169 - f1_score: 0.0371 - val_loss: 2.2989 - val_accuracy: 0.1143 - val_f1_score: 0.0205
# Epoch 6/100
# 716/716 [==============================] - 30s 42ms/step - loss: 2.2989 - accuracy: 0.1195 - f1_score: 0.0379 - val_loss: 2.2984 - val_accuracy: 0.1143 - val_f1_score: 0.0205
# Epoch 7/100
# 716/716 [==============================] - 30s 42ms/step - loss: 2.2984 - accuracy: 0.1211 - f1_score: 0.0388 - val_loss: 2.2979 - val_accuracy: 0.1150 - val_f1_score: 0.0230
# Epoch 8/100
# 716/716 [==============================] - 30s 42ms/step - loss: 2.2976 - accuracy: 0.1247 - f1_score: 0.0400 - val_loss: 2.2973 - val_accuracy: 0.1210 - val_f1_score: 0.0304
# Epoch 9/100
# 716/716 [==============================] - 30s 42ms/step - loss: 2.2971 - accuracy: 0.1248 - f1_score: 0.0402 - val_loss: 2.2964 - val_accuracy: 0.1294 - val_f1_score: 0.0362
# Epoch 10/100
# 716/716 [==============================] - 30s 42ms/step - loss: 2.2961 - accuracy: 0.1257 - f1_score: 0.0408 - val_loss: 2.2950 - val_accuracy: 0.1325 - val_f1_score: 0.0391
# Epoch 11/100
# 716/716 [==============================] - 30s 42ms/step - loss: 2.2945 - accuracy: 0.1252 - f1_score: 0.0410 - val_loss: 2.2926 - val_accuracy: 0.1378 - val_f1_score: 0.0422
# Epoch 12/100
# 716/716 [==============================] - 30s 42ms/step - loss: 2.2913 - accuracy: 0.1321 - f1_score: 0.0497 - val_loss: 2.2874 - val_accuracy: 0.1430 - val_f1_score: 0.0453
# Epoch 13/100
# 716/716 [==============================] - 30s 42ms/step - loss: 2.2833 - accuracy: 0.1432 - f1_score: 0.0811 - val_loss: 2.2722 - val_accuracy: 0.1657 - val_f1_score: 0.0595
# Epoch 14/100
# 716/716 [==============================] - 30s 42ms/step - loss: 2.2601 - accuracy: 0.1605 - f1_score: 0.1225 - val_loss: 2.2231 - val_accuracy: 0.1853 - val_f1_score: 0.0940
# Epoch 15/100
# 716/716 [==============================] - 30s 42ms/step - loss: 2.1963 - accuracy: 0.1925 - f1_score: 0.1703 - val_loss: 2.1305 - val_accuracy: 0.2329 - val_f1_score: 0.1668
# Epoch 16/100
# 716/716 [==============================] - 30s 42ms/step - loss: 2.1408 - accuracy: 0.2194 - f1_score: 0.2006 - val_loss: 2.1014 - val_accuracy: 0.2329 - val_f1_score: 0.1658
# Epoch 17/100
# 716/716 [==============================] - 30s 42ms/step - loss: 2.1129 - accuracy: 0.2320 - f1_score: 0.2132 - val_loss: 2.0626 - val_accuracy: 0.2668 - val_f1_score: 0.2248
# Epoch 18/100
# 716/716 [==============================] - 30s 42ms/step - loss: 2.0853 - accuracy: 0.2483 - f1_score: 0.2282 - val_loss: 2.0667 - val_accuracy: 0.2549 - val_f1_score: 0.1997
# Epoch 19/100
# 716/716 [==============================] - 30s 42ms/step - loss: 2.0717 - accuracy: 0.2543 - f1_score: 0.2361 - val_loss: 2.0390 - val_accuracy: 0.2671 - val_f1_score: 0.2173
# Epoch 20/100
# 716/716 [==============================] - 30s 42ms/step - loss: 2.0504 - accuracy: 0.2617 - f1_score: 0.2447 - val_loss: 2.0078 - val_accuracy: 0.2815 - val_f1_score: 0.2454
# Epoch 21/100
# 716/716 [==============================] - 30s 42ms/step - loss: 2.0270 - accuracy: 0.2781 - f1_score: 0.2617 - val_loss: 1.9813 - val_accuracy: 0.3052 - val_f1_score: 0.2779
# Epoch 22/100
# 716/716 [==============================] - 30s 42ms/step - loss: 2.0040 - accuracy: 0.2861 - f1_score: 0.2720 - val_loss: 1.9516 - val_accuracy: 0.3164 - val_f1_score: 0.2926
# Epoch 23/100
# 716/716 [==============================] - 30s 42ms/step - loss: 1.9718 - accuracy: 0.3038 - f1_score: 0.2919 - val_loss: 1.8874 - val_accuracy: 0.3336 - val_f1_score: 0.3069
# Epoch 24/100
# 716/716 [==============================] - 30s 42ms/step - loss: 1.9443 - accuracy: 0.3136 - f1_score: 0.3022 - val_loss: 1.8772 - val_accuracy: 0.3336 - val_f1_score: 0.3010
# Epoch 25/100
# 716/716 [==============================] - 30s 42ms/step - loss: 1.9003 - accuracy: 0.3318 - f1_score: 0.3232 - val_loss: 1.8551 - val_accuracy: 0.3619 - val_f1_score: 0.3374
# Epoch 26/100
# 716/716 [==============================] - 30s 42ms/step - loss: 1.8629 - accuracy: 0.3566 - f1_score: 0.3473 - val_loss: 1.8703 - val_accuracy: 0.3462 - val_f1_score: 0.3000
# Epoch 27/100
# 716/716 [==============================] - 30s 42ms/step - loss: 1.8200 - accuracy: 0.3647 - f1_score: 0.3569 - val_loss: 1.8076 - val_accuracy: 0.3780 - val_f1_score: 0.3478
# Epoch 28/100
# 716/716 [==============================] - 30s 42ms/step - loss: 1.7707 - accuracy: 0.3826 - f1_score: 0.3760 - val_loss: 1.7169 - val_accuracy: 0.4185 - val_f1_score: 0.4035
# Epoch 29/100
# 716/716 [==============================] - 30s 42ms/step - loss: 1.7229 - accuracy: 0.4056 - f1_score: 0.3975 - val_loss: 1.7572 - val_accuracy: 0.4080 - val_f1_score: 0.3937
# Epoch 30/100
# 716/716 [==============================] - 30s 42ms/step - loss: 1.6564 - accuracy: 0.4349 - f1_score: 0.4273 - val_loss: 1.6295 - val_accuracy: 0.4580 - val_f1_score: 0.4548
# Epoch 31/100
# 716/716 [==============================] - 30s 42ms/step - loss: 1.5999 - accuracy: 0.4564 - f1_score: 0.4499 - val_loss: 1.6145 - val_accuracy: 0.4587 - val_f1_score: 0.4490
# Epoch 32/100
# 716/716 [==============================] - 30s 42ms/step - loss: 1.5404 - accuracy: 0.4858 - f1_score: 0.4790 - val_loss: 1.5434 - val_accuracy: 0.4888 - val_f1_score: 0.4812
# Epoch 33/100
# 716/716 [==============================] - 30s 42ms/step - loss: 1.4821 - accuracy: 0.5001 - f1_score: 0.4938 - val_loss: 1.5026 - val_accuracy: 0.5000 - val_f1_score: 0.4971
# Epoch 34/100
# 716/716 [==============================] - 30s 42ms/step - loss: 1.4001 - accuracy: 0.5329 - f1_score: 0.5276 - val_loss: 1.4939 - val_accuracy: 0.5091 - val_f1_score: 0.4982
# Epoch 35/100
# 716/716 [==============================] - 30s 42ms/step - loss: 1.3489 - accuracy: 0.5509 - f1_score: 0.5454 - val_loss: 1.4075 - val_accuracy: 0.5339 - val_f1_score: 0.5274
# Epoch 36/100
# 716/716 [==============================] - 30s 42ms/step - loss: 1.2675 - accuracy: 0.5807 - f1_score: 0.5752 - val_loss: 1.3837 - val_accuracy: 0.5476 - val_f1_score: 0.5367
# Epoch 37/100
# 716/716 [==============================] - 30s 42ms/step - loss: 1.2019 - accuracy: 0.6022 - f1_score: 0.5966 - val_loss: 1.3002 - val_accuracy: 0.5734 - val_f1_score: 0.5647
# Epoch 38/100
# 716/716 [==============================] - 30s 42ms/step - loss: 1.1294 - accuracy: 0.6265 - f1_score: 0.6218 - val_loss: 1.3808 - val_accuracy: 0.5462 - val_f1_score: 0.5486
# Epoch 39/100
# 716/716 [==============================] - 30s 42ms/step - loss: 1.0634 - accuracy: 0.6477 - f1_score: 0.6437 - val_loss: 1.4143 - val_accuracy: 0.5269 - val_f1_score: 0.5349
# Epoch 40/100
# 716/716 [==============================] - 30s 42ms/step - loss: 1.0047 - accuracy: 0.6715 - f1_score: 0.6674 - val_loss: 1.2501 - val_accuracy: 0.6122 - val_f1_score: 0.6090
# Epoch 41/100
# 716/716 [==============================] - 30s 42ms/step - loss: 0.9127 - accuracy: 0.6949 - f1_score: 0.6910 - val_loss: 1.2630 - val_accuracy: 0.6112 - val_f1_score: 0.6053
# Epoch 42/100
# 716/716 [==============================] - 30s 42ms/step - loss: 0.8662 - accuracy: 0.7139 - f1_score: 0.7105 - val_loss: 1.2692 - val_accuracy: 0.6227 - val_f1_score: 0.6179
# Epoch 43/100
# 716/716 [==============================] - 30s 42ms/step - loss: 0.7988 - accuracy: 0.7395 - f1_score: 0.7362 - val_loss: 1.3806 - val_accuracy: 0.5724 - val_f1_score: 0.5624
# Epoch 44/100
# 716/716 [==============================] - 30s 42ms/step - loss: 0.7265 - accuracy: 0.7611 - f1_score: 0.7585 - val_loss: 1.1341 - val_accuracy: 0.6696 - val_f1_score: 0.6634
# Epoch 45/100
# 716/716 [==============================] - 30s 42ms/step - loss: 0.6750 - accuracy: 0.7788 - f1_score: 0.7763 - val_loss: 1.1250 - val_accuracy: 0.6734 - val_f1_score: 0.6703
# Epoch 46/100
# 716/716 [==============================] - 30s 42ms/step - loss: 0.6380 - accuracy: 0.7843 - f1_score: 0.7819 - val_loss: 1.1466 - val_accuracy: 0.6689 - val_f1_score: 0.6687
# Epoch 47/100
# 716/716 [==============================] - 30s 42ms/step - loss: 0.5420 - accuracy: 0.8193 - f1_score: 0.8174 - val_loss: 1.2189 - val_accuracy: 0.6531 - val_f1_score: 0.6506
# Epoch 48/100
# 716/716 [==============================] - 30s 42ms/step - loss: 0.5001 - accuracy: 0.8319 - f1_score: 0.8297 - val_loss: 1.1930 - val_accuracy: 0.6738 - val_f1_score: 0.6667
# Epoch 49/100
# 716/716 [==============================] - 30s 42ms/step - loss: 0.4837 - accuracy: 0.8400 - f1_score: 0.8380 - val_loss: 1.1335 - val_accuracy: 0.6801 - val_f1_score: 0.6800
# Epoch 50/100
# 716/716 [==============================] - 30s 42ms/step - loss: 0.4384 - accuracy: 0.8536 - f1_score: 0.8521 - val_loss: 1.2463 - val_accuracy: 0.6682 - val_f1_score: 0.6702
# Epoch 51/100
# 716/716 [==============================] - 30s 42ms/step - loss: 0.4088 - accuracy: 0.8613 - f1_score: 0.8598 - val_loss: 1.2238 - val_accuracy: 0.6748 - val_f1_score: 0.6761
# Epoch 52/100
# 716/716 [==============================] - 30s 42ms/step - loss: 0.3653 - accuracy: 0.8736 - f1_score: 0.8723 - val_loss: 1.2201 - val_accuracy: 0.6832 - val_f1_score: 0.6796
# Epoch 53/100
# 716/716 [==============================] - 30s 42ms/step - loss: 0.3374 - accuracy: 0.8874 - f1_score: 0.8864 - val_loss: 1.1740 - val_accuracy: 0.7024 - val_f1_score: 0.7007
# Epoch 54/100
# 716/716 [==============================] - 30s 42ms/step - loss: 0.2991 - accuracy: 0.8980 - f1_score: 0.8971 - val_loss: 1.3902 - val_accuracy: 0.6766 - val_f1_score: 0.6758
# Epoch 55/100
# 716/716 [==============================] - 30s 42ms/step - loss: 0.3298 - accuracy: 0.8912 - f1_score: 0.8899 - val_loss: 1.2181 - val_accuracy: 0.6979 - val_f1_score: 0.6968
# Epoch 56/100
# 716/716 [==============================] - 30s 42ms/step - loss: 0.2565 - accuracy: 0.9135 - f1_score: 0.9126 - val_loss: 1.3421 - val_accuracy: 0.6965 - val_f1_score: 0.6928
# Epoch 57/100
# 716/716 [==============================] - 30s 42ms/step - loss: 0.2367 - accuracy: 0.9228 - f1_score: 0.9219 - val_loss: 1.3439 - val_accuracy: 0.7143 - val_f1_score: 0.7091
# Epoch 58/100
# 716/716 [==============================] - 30s 42ms/step - loss: 0.2286 - accuracy: 0.9229 - f1_score: 0.9221 - val_loss: 1.2389 - val_accuracy: 0.7056 - val_f1_score: 0.7034
# Epoch 59/100
# 716/716 [==============================] - 30s 42ms/step - loss: 0.2163 - accuracy: 0.9281 - f1_score: 0.9275 - val_loss: 1.1944 - val_accuracy: 0.7217 - val_f1_score: 0.7204
# Epoch 60/100
# 716/716 [==============================] - 30s 42ms/step - loss: 0.1939 - accuracy: 0.9367 - f1_score: 0.9363 - val_loss: 1.2160 - val_accuracy: 0.7343 - val_f1_score: 0.7316
# Epoch 61/100
# 716/716 [==============================] - 30s 42ms/step - loss: 0.1715 - accuracy: 0.9425 - f1_score: 0.9420 - val_loss: 1.2783 - val_accuracy: 0.7178 - val_f1_score: 0.7136
# Epoch 62/100
# 716/716 [==============================] - 30s 42ms/step - loss: 0.1747 - accuracy: 0.9402 - f1_score: 0.9398 - val_loss: 1.3129 - val_accuracy: 0.7339 - val_f1_score: 0.7302
# Epoch 63/100
# 716/716 [==============================] - 30s 42ms/step - loss: 0.1544 - accuracy: 0.9489 - f1_score: 0.9483 - val_loss: 1.2803 - val_accuracy: 0.7339 - val_f1_score: 0.7315
# Epoch 64/100
# 716/716 [==============================] - 30s 42ms/step - loss: 0.1514 - accuracy: 0.9520 - f1_score: 0.9515 - val_loss: 1.2691 - val_accuracy: 0.7315 - val_f1_score: 0.7290
# Epoch 65/100
# 716/716 [==============================] - 30s 42ms/step - loss: 0.1476 - accuracy: 0.9521 - f1_score: 0.9516 - val_loss: 1.2932 - val_accuracy: 0.7336 - val_f1_score: 0.7275
# Epoch 66/100
# 716/716 [==============================] - 30s 42ms/step - loss: 0.1239 - accuracy: 0.9587 - f1_score: 0.9584 - val_loss: 1.4498 - val_accuracy: 0.7164 - val_f1_score: 0.7141
# Epoch 67/100
# 716/716 [==============================] - 30s 42ms/step - loss: 0.1321 - accuracy: 0.9545 - f1_score: 0.9541 - val_loss: 1.3698 - val_accuracy: 0.7297 - val_f1_score: 0.7268
# Epoch 68/100
# 716/716 [==============================] - 30s 42ms/step - loss: 0.1140 - accuracy: 0.9630 - f1_score: 0.9628 - val_loss: 1.2618 - val_accuracy: 0.7357 - val_f1_score: 0.7318
# Epoch 69/100
# 716/716 [==============================] - 30s 42ms/step - loss: 0.1197 - accuracy: 0.9615 - f1_score: 0.9611 - val_loss: 1.3098 - val_accuracy: 0.7301 - val_f1_score: 0.7306
# Epoch 70/100
# 716/716 [==============================] - 30s 42ms/step - loss: 0.1142 - accuracy: 0.9645 - f1_score: 0.9643 - val_loss: 1.3965 - val_accuracy: 0.7224 - val_f1_score: 0.7269
# Epoch 71/100
# 716/716 [==============================] - 30s 42ms/step - loss: 0.1079 - accuracy: 0.9644 - f1_score: 0.9644 - val_loss: 1.3602 - val_accuracy: 0.7248 - val_f1_score: 0.7215
# Epoch 72/100
# 716/716 [==============================] - 30s 42ms/step - loss: 0.1071 - accuracy: 0.9649 - f1_score: 0.9645 - val_loss: 1.3765 - val_accuracy: 0.7444 - val_f1_score: 0.7405
# Epoch 73/100
# 716/716 [==============================] - 30s 42ms/step - loss: 0.0953 - accuracy: 0.9678 - f1_score: 0.9675 - val_loss: 1.2768 - val_accuracy: 0.7458 - val_f1_score: 0.7440
# Epoch 74/100
# 716/716 [==============================] - 30s 42ms/step - loss: 0.0905 - accuracy: 0.9696 - f1_score: 0.9694 - val_loss: 1.2879 - val_accuracy: 0.7413 - val_f1_score: 0.7378
# Epoch 75/100
# 716/716 [==============================] - 30s 42ms/step - loss: 0.0748 - accuracy: 0.9750 - f1_score: 0.9748 - val_loss: 1.3529 - val_accuracy: 0.7423 - val_f1_score: 0.7430
# Epoch 76/100
# 716/716 [==============================] - 30s 42ms/step - loss: 0.0821 - accuracy: 0.9729 - f1_score: 0.9727 - val_loss: 1.3529 - val_accuracy: 0.7339 - val_f1_score: 0.7333
# Epoch 77/100
# 716/716 [==============================] - 30s 42ms/step - loss: 0.0863 - accuracy: 0.9728 - f1_score: 0.9727 - val_loss: 1.3709 - val_accuracy: 0.7241 - val_f1_score: 0.7210
# Epoch 78/100
# 716/716 [==============================] - 30s 42ms/step - loss: 0.0705 - accuracy: 0.9765 - f1_score: 0.9763 - val_loss: 1.6234 - val_accuracy: 0.7000 - val_f1_score: 0.7069
# Epoch 79/100
# 716/716 [==============================] - 30s 42ms/step - loss: 0.0781 - accuracy: 0.9744 - f1_score: 0.9742 - val_loss: 1.3978 - val_accuracy: 0.7409 - val_f1_score: 0.7388
# Epoch 80/100
# 716/716 [==============================] - 30s 42ms/step - loss: 0.0947 - accuracy: 0.9695 - f1_score: 0.9693 - val_loss: 1.3549 - val_accuracy: 0.7531 - val_f1_score: 0.7515
# Epoch 81/100
# 716/716 [==============================] - 30s 42ms/step - loss: 0.0678 - accuracy: 0.9769 - f1_score: 0.9767 - val_loss: 1.2858 - val_accuracy: 0.7497 - val_f1_score: 0.7461
# Epoch 82/100
# 716/716 [==============================] - 30s 42ms/step - loss: 0.0854 - accuracy: 0.9722 - f1_score: 0.9720 - val_loss: 1.2867 - val_accuracy: 0.7409 - val_f1_score: 0.7408
# Epoch 83/100
# 716/716 [==============================] - 30s 42ms/step - loss: 0.0728 - accuracy: 0.9755 - f1_score: 0.9753 - val_loss: 1.3417 - val_accuracy: 0.7552 - val_f1_score: 0.7550
# Epoch 84/100
# 716/716 [==============================] - 30s 42ms/step - loss: 0.0516 - accuracy: 0.9822 - f1_score: 0.9820 - val_loss: 1.4254 - val_accuracy: 0.7469 - val_f1_score: 0.7432
# Epoch 85/100
# 716/716 [==============================] - 30s 42ms/step - loss: 0.0506 - accuracy: 0.9841 - f1_score: 0.9840 - val_loss: 1.6846 - val_accuracy: 0.7301 - val_f1_score: 0.7256
# Epoch 86/100
# 716/716 [==============================] - 30s 42ms/step - loss: 0.0518 - accuracy: 0.9830 - f1_score: 0.9829 - val_loss: 1.3379 - val_accuracy: 0.7594 - val_f1_score: 0.7562
# Epoch 87/100
# 716/716 [==============================] - 30s 41ms/step - loss: 0.0488 - accuracy: 0.9824 - f1_score: 0.9822 - val_loss: 1.5908 - val_accuracy: 0.7367 - val_f1_score: 0.7391
# Epoch 88/100
# 716/716 [==============================] - 30s 42ms/step - loss: 0.0528 - accuracy: 0.9830 - f1_score: 0.9829 - val_loss: 1.5799 - val_accuracy: 0.7472 - val_f1_score: 0.7409
# Epoch 89/100
# 716/716 [==============================] - 30s 42ms/step - loss: 0.0465 - accuracy: 0.9860 - f1_score: 0.9860 - val_loss: 1.3793 - val_accuracy: 0.7563 - val_f1_score: 0.7550
# Epoch 90/100
# 716/716 [==============================] - 30s 41ms/step - loss: 0.0446 - accuracy: 0.9844 - f1_score: 0.9842 - val_loss: 1.4576 - val_accuracy: 0.7570 - val_f1_score: 0.7522
# Epoch 91/100
# 716/716 [==============================] - 30s 41ms/step - loss: 0.0540 - accuracy: 0.9826 - f1_score: 0.9824 - val_loss: 1.5310 - val_accuracy: 0.7559 - val_f1_score: 0.7528
# Epoch 92/100
# 716/716 [==============================] - 30s 41ms/step - loss: 0.0478 - accuracy: 0.9848 - f1_score: 0.9846 - val_loss: 1.4620 - val_accuracy: 0.7549 - val_f1_score: 0.7544
# Epoch 93/100
# 716/716 [==============================] - 30s 41ms/step - loss: 0.0404 - accuracy: 0.9878 - f1_score: 0.9877 - val_loss: 1.5316 - val_accuracy: 0.7493 - val_f1_score: 0.7453
# Epoch 94/100
# 716/716 [==============================] - 30s 41ms/step - loss: 0.0342 - accuracy: 0.9886 - f1_score: 0.9885 - val_loss: 1.4767 - val_accuracy: 0.7524 - val_f1_score: 0.7511
# Epoch 95/100
# 716/716 [==============================] - 30s 41ms/step - loss: 0.0418 - accuracy: 0.9862 - f1_score: 0.9862 - val_loss: 1.5525 - val_accuracy: 0.7507 - val_f1_score: 0.7476
# Epoch 96/100
# 716/716 [==============================] - 30s 41ms/step - loss: 0.0446 - accuracy: 0.9865 - f1_score: 0.9864 - val_loss: 1.4648 - val_accuracy: 0.7570 - val_f1_score: 0.7550
# Epoch 97/100
# 716/716 [==============================] - 30s 42ms/step - loss: 0.0426 - accuracy: 0.9861 - f1_score: 0.9861 - val_loss: 1.4536 - val_accuracy: 0.7626 - val_f1_score: 0.7580
# Epoch 98/100
# 716/716 [==============================] - 30s 41ms/step - loss: 0.0366 - accuracy: 0.9879 - f1_score: 0.9879 - val_loss: 1.4431 - val_accuracy: 0.7538 - val_f1_score: 0.7511
# Epoch 99/100
# 716/716 [==============================] - 30s 41ms/step - loss: 0.0423 - accuracy: 0.9870 - f1_score: 0.9869 - val_loss: 1.4780 - val_accuracy: 0.7517 - val_f1_score: 0.7491
# Epoch 100/100
# 716/716 [==============================] - 30s 41ms/step - loss: 0.0326 - accuracy: 0.9887 - f1_score: 0.9886 - val_loss: 1.5282 - val_accuracy: 0.7594 - val_f1_score: 0.7563

# %%
def plot_results(history, epochs, FE_name= "ResNet50", model_name= "ResNet50_model", version= 1):
    import os
    ## Create the dataframe
    data = pd.DataFrame()
    data["Epoch"] = [i for i in range(epochs)]
    data["loss"] = history.history["loss"]
    data["val_loss"] = history.history["val_loss"]
    data["accuracy"] = history.history["accuracy"]
    data["val_accuracy"] = history.history["val_accuracy"]
    data["f1_score"] = history.history["f1_score"]
    data["val_f1_score"] = history.history["val_f1_score"]

    ## Create subplots
    fig, ax= plt.subplots(1, 3, figsize = (19, 7))

    ## plot loss
    sns.lineplot(x= "Epoch", y= "loss", data = data, ax= ax[0])
    sns.lineplot(x= "Epoch", y= "val_loss", data = data, ax= ax[0])
    ax[0].legend(["train_loss", "val_loss"], loc= 'best')
    ax[0].title.set_text("Categorical Cross Entropy")

    ## plot accuracy
    sns.lineplot(x = "Epoch", y = "accuracy", data = data, ax = ax[1])
    sns.lineplot(x = "Epoch", y = "val_accuracy", data = data, ax = ax[1])
    ax[1].legend(["train_accuracy", "val_accuracy"], loc='best')
    ax[1].title.set_text("Categorical Accuracy")

    ## plot f1
    sns.lineplot(x = "Epoch", y = "f1_score", data = data, ax = ax[2])
    sns.lineplot(x = "Epoch", y = "val_f1_score", data = data, ax = ax[2])
    ax[2].legend(["f1_score_macro", "val_f1_score_macro"], loc='best')
    ax[2].title.set_text("F1 Score Macro")


    ## Remove padding
    fig.tight_layout()

plot_results(history, epochs = 100, FE_name = "VGG16", model_name = "VGG16_exp1")

# %%
test_data.classes
# Out:
# array([0, 0, 0, ..., 9, 9, 9], dtype=int32)

# %%
model.evaluate(test_data, batch_size= 16, return_dict= True)
# Out:
# 94/94 [==============================] - 10s 101ms/step - loss: 1.0745 - accuracy: 0.8127 - f1_score: 0.8121
# {'loss': 1.0745186805725098,
#  'accuracy': 0.812666654586792,
#  'f1_score': 0.8121035695075989}

# %%
test_data.classes
# Out:
# array([0, 0, 0, ..., 9, 9, 9], dtype=int32)

# %%
# Generating Confusion Matrix and Classification Report
Y_pred= model.predict_generator(test_data, 1500// 16 + 1)
y_pred= np.argmax(Y_pred, axis= 1)
print('Confusion Matrix')
conf_matrix= confusion_matrix(test_data.classes, y_pred)
conf_mat = np.array2string(conf_matrix)
#print(conf_matrix)
#print("=============================================================================================")
print('Classification Report')
target_names= test_data.class_indices
class_rep_vgg = classification_report(test_data.classes, y_pred, target_names=target_names)
print(class_rep_vgg)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
# Confusion Matrix
# Classification Report
#                           precision    recall  f1-score   support
#
#    bacterial_leaf_blight       0.79      0.66      0.72       150
#    bacterial_leaf_streak       0.87      0.85      0.86       150
# bacterial_panicle_blight       0.78      0.81      0.79       150
#                    blast       0.85      0.83      0.84       150
#               brown_spot       0.74      0.79      0.76       150
#               dead_heart       0.80      0.88      0.84       150
#             downy_mildew       0.87      0.85      0.86       150
#                    hispa       0.79      0.85      0.82       150
#                   normal       0.86      0.83      0.84       150
#                   tungro       0.78      0.78      0.78       150
#
#                 accuracy                           0.81      1500
#                macro avg       0.81      0.81      0.81      1500
#             weighted avg       0.81      0.81      0.81      1500

# %%
ConfusionMatrixDisplay.from_predictions(test_data.classes, y_pred, display_labels= target_names, xticks_rotation= 'vertical')
