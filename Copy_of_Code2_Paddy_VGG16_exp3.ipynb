# %% [markdown]
# <a href="https://colab.research.google.com/github/anikch/paddy/blob/main/Copy_of_Code2_Paddy_VGG16_exp3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow_addons
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow_addons
#   Downloading tensorflow_addons-0.18.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 5.1 MB/s
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow_addons) (2.7.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tensorflow_addons) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tensorflow_addons) (3.0.9)
# Installing collected packages: tensorflow-addons
# Successfully installed tensorflow-addons-0.18.0

# %%
# !pip install keras_cv
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting keras_cv
#   Downloading keras_cv-0.3.4-py3-none-any.whl (394 kB)
#      |████████████████████████████████| 394 kB 5.2 MB/s
# Requirement already satisfied: absl-py in /usr/local/lib/python3.7/dist-packages (from keras_cv) (1.3.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from keras_cv) (2022.6.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from keras_cv) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->keras_cv) (3.0.9)
# Installing collected packages: keras-cv
# Successfully installed keras-cv-0.3.4

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import tensorflow_addons as tfa
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import seaborn as sns
from typing import List
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from functools import partial
import posixpath
from keras import models, regularizers, layers, optimizers, losses, metrics
import keras_cv
from keras.models import Sequential
from keras.layers import Dense
from tensorflow.keras.utils import plot_model

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !nvidia-smi
# Out:
# Mon Oct 24 19:55:59 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  A100-SXM4-40GB      Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    42W / 400W |      0MiB / 40536MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
colab= '/content/drive/MyDrive'
local= r'G:\My Drive'

code_runtime= colab

# %%
tf.__version__
# Out:
# '2.9.2'

# %%
file1= 'thesis/dataset/paddy_doctor/train.csv'
inp_file = posixpath.join(code_runtime, file1)

train_table=pd.read_csv(inp_file)
train_table
# Out:
#          image_id                  label variety  age
# 0      100330.jpg  bacterial_leaf_blight   ADT45   45
# 1      100365.jpg  bacterial_leaf_blight   ADT45   45
# 2      100382.jpg  bacterial_leaf_blight   ADT45   45
# 3      100632.jpg  bacterial_leaf_blight   ADT45   45
# 4      101918.jpg  bacterial_leaf_blight   ADT45   45
# ...           ...                    ...     ...  ...
# 10402  107607.jpg                 tungro   Zonal   55
# 10403  107811.jpg                 tungro   Zonal   55
# 10404  108547.jpg                 tungro   Zonal   55
# 10405  110245.jpg                 tungro   Zonal   55
# 10406  110381.jpg                 tungro   Zonal   55
#
# [10407 rows x 4 columns]

# %%
labels=list(np.unique(train_table['label']))
labels
# Out:
# ['bacterial_leaf_blight',
#  'bacterial_leaf_streak',
#  'bacterial_panicle_blight',
#  'blast',
#  'brown_spot',
#  'dead_heart',
#  'downy_mildew',
#  'hispa',
#  'normal',
#  'tungro']

# %%
train_dir= 'thesis/dataset/paddy_doctor/train/'
val_dir= 'thesis/dataset/paddy_doctor/val/'
img_size= 224

train_files= posixpath.join(code_runtime, train_dir)
test_files= posixpath.join(code_runtime, val_dir)

train_data= tf.keras.utils.image_dataset_from_directory(train_files,
                                                        labels='inferred',
                                                        label_mode='categorical',
                                                        validation_split=0.2,
                                                        subset="training",
                                                        class_names=labels,
                                                        color_mode='rgb',
                                                        image_size=(img_size, img_size),
                                                        shuffle=True,
                                                        seed= 42,
                                                        batch_size= 16)

val_data= tf.keras.utils.image_dataset_from_directory(train_files,
                                                        labels= 'inferred',
                                                        label_mode='categorical',
                                                        validation_split=0.2,
                                                        subset="validation",
                                                        class_names= labels,
                                                        color_mode='rgb',
                                                        image_size=(img_size, img_size),
                                                        shuffle=True,
                                                        seed= 42,
                                                        batch_size= 16)


test_datagen= ImageDataGenerator()
test_data= test_datagen.flow_from_directory(test_files,
                                            target_size= (img_size, img_size),
                                            batch_size= 16,
                                            shuffle = False, 
                                            class_mode='categorical')
# Out:
# Found 14302 files belonging to 10 classes.
# Using 11442 files for training.
# Found 14302 files belonging to 10 classes.
# Using 2860 files for validation.
# Found 1500 images belonging to 10 classes.

# %%
class_names = train_data.class_names
print(class_names)
# Out:
# ['bacterial_leaf_blight', 'bacterial_leaf_streak', 'bacterial_panicle_blight', 'blast', 'brown_spot', 'dead_heart', 'downy_mildew', 'hispa', 'normal', 'tungro']

# %%
test_data.class_indices
# Out:
# {'bacterial_leaf_blight': 0,
#  'bacterial_leaf_streak': 1,
#  'bacterial_panicle_blight': 2,
#  'blast': 3,
#  'brown_spot': 4,
#  'dead_heart': 5,
#  'downy_mildew': 6,
#  'hispa': 7,
#  'normal': 8,
#  'tungro': 9}

# %% [markdown]
# ## Augmentation Pipeline

# %%
# data augmentation
def augment_train_data(images, labels):
  inputs= {"images": images, "labels": labels}
  layers= keras_cv.layers.RandAugment.get_standard_policy(value_range=(0, 255), geometric= True, magnitude= 0.75, magnitude_stddev= 0.3)
  layers= layers + [keras_cv.layers.preprocessing.RandomFlip(mode= 'horizontal'),
                    keras_cv.layers.preprocessing.RandomRotation(factor= .1, seed= 42),
                    keras_cv.layers.GridMask(ratio_factor= (.0, .3), rotation_factor= (.0,.1), fill_mode= 'gaussian_noise'), 
                    #keras_cv.layers.RandomColorJitter(brightness_factor= .5, contrast_factor= .5, hue_factor= .2, saturation_factor= (.1, .9), value_range= [0, 255])
                    ]
  aug_pipeline= keras_cv.layers.RandomAugmentationPipeline(layers= layers, augmentations_per_image= 3)
  outputs= aug_pipeline(inputs)
  print(*layers)
  return outputs['images'], outputs['labels']

# %%
AUTOTUNE= tf.data.AUTOTUNE
train_aug_ds= train_data.map(augment_train_data, num_parallel_calls= tf.data.AUTOTUNE).prefetch(tf.data.AUTOTUNE)
val_ds= val_data.prefetch(buffer_size= AUTOTUNE)
# Out:
# <keras_cv.layers.preprocessing.auto_contrast.AutoContrast object at 0x7f3d543067d0> <keras_cv.layers.preprocessing.equalization.Equalization object at 0x7f3db04437d0> <keras_cv.layers.preprocessing.solarization.Solarization object at 0x7f3d22d84590> <keras_cv.layers.preprocessing.random_color_degeneration.RandomColorDegeneration object at 0x7f3d540a7490> <keras.layers.preprocessing.image_preprocessing.RandomContrast object at 0x7f3d22d84b50> <keras.layers.preprocessing.image_preprocessing.RandomBrightness object at 0x7f3d54285a10> <keras_cv.layers.preprocessing.random_shear.RandomShear object at 0x7f3d246f2f50> <keras_cv.layers.preprocessing.random_shear.RandomShear object at 0x7f3d22d831d0> <keras.layers.preprocessing.image_preprocessing.RandomTranslation object at 0x7f3d22d83590> <keras.layers.preprocessing.image_preprocessing.RandomTranslation object at 0x7f3d22d83510> <keras_cv.layers.preprocessing.random_flip.RandomFlip object at 0x7f3d2472e810> <keras_cv.layers.preprocessing.random_rotation.RandomRotation object at 0x7f3d540377d0> <keras_cv.layers.preprocessing.grid_mask.GridMask object at 0x7f3d246f2950>

# %% [markdown]
# ## VGG16 (Augmentation + Transfer Learning + Fine Tune)

# %%
base_model= tf.keras.applications.VGG16(
    include_top= False,
    weights= 'imagenet',
    input_shape=(img_size, img_size, 3),
    pooling= 'max'
)

# %%
tf.keras.utils.plot_model(
    base_model,
    show_shapes= True,
    show_dtype=False,
    show_layer_names=True,
    rankdir="TR",
    expand_nested=False,
    dpi=72,
    layer_range=None,
    show_layer_activations=True,
)

# %%
inputs= tf.keras.Input(shape= (img_size, img_size, 3))
preprocess_layer= tf.keras.applications.vgg16.preprocess_input(inputs)
normalization_layer= tf.keras.layers.Rescaling(scale= 1./127.5, offset= -1)(preprocess_layer)
x= base_model(normalization_layer)
x= tf.keras.layers.Dropout(0.25)(x)
outputs= tf.keras.layers.Dense(10, activation= 'softmax')(x)

# %%
model= tf.keras.Model(inputs= inputs, outputs= outputs, name= "vgg16_TL_augmentation")

# %%
model.summary()
# Out:
# Model: "vgg16_TL_augmentation"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_1   (None, 224, 224, 3)      0
#  (SlicingOpLambda)
#
#  tf.nn.bias_add_1 (TFOpLambd  (None, 224, 224, 3)      0
#  a)
#
#  rescaling_1 (Rescaling)     (None, 224, 224, 3)       0
#
#  vgg16 (Functional)          (None, 512)               14714688
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 14,719,818
# Trainable params: 14,719,818
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(
    model,
    show_shapes= True,
    show_dtype=False,
    show_layer_names=True,
    rankdir="TR",
    expand_nested=False,
    dpi=72,
    layer_range=None,
    show_layer_activations=True,
)

# %%
# %%time
n_epochs= 100

filepath= "weights-improvement-{epoch:02d}-{val_accuracy:.4f}.hdf5"
checkpoint_callback= ModelCheckpoint(filepath, monitor= 'val_accuracy', verbose= 1, save_best_only= True, mode= 'max')
early_stop_callback= EarlyStopping(monitor='val_accuracy', patience= 5, verbose= False, mode='max')
callbacks_list=[checkpoint_callback, early_stop_callback]
# Out:
# CPU times: user 103 µs, sys: 19 µs, total: 122 µs
# Wall time: 127 µs

# %%
optimizer_adam_amsgrad= tf.keras.optimizers.Adam(learning_rate= 1e-4, amsgrad= True)
optimizer_adam= tf.keras.optimizers.Adam(learning_rate= 1e-4, amsgrad= False)
optimizer_sgd= tf.keras.optimizers.SGD(learning_rate= 1e-4, momentum= 0.9)

# %%
model.compile(
        optimizer = optimizer_sgd,
        loss = 'categorical_crossentropy', 
        metrics = ['accuracy', tfa.metrics.F1Score(average='macro', num_classes= 10)]
        )

# %%
history= model.fit(train_aug_ds,
                  epochs= n_epochs,
                  validation_data= val_ds,
                  callbacks= callbacks_list,
                  verbose= 1)
# Out:
# Epoch 1/100
# 716/716 [==============================] - ETA: 0s - loss: 2.0063 - accuracy: 0.2738 - f1_score: 0.2685
# Epoch 1: val_accuracy improved from -inf to 0.48462, saving model to weights-improvement-01-0.4846.hdf5
# 716/716 [==============================] - 246s 342ms/step - loss: 2.0063 - accuracy: 0.2738 - f1_score: 0.2685 - val_loss: 1.4319 - val_accuracy: 0.4846 - val_f1_score: 0.4624
# Epoch 2/100
# 714/716 [============================>.] - ETA: 0s - loss: 1.2318 - accuracy: 0.5643 - f1_score: 0.5595
# Epoch 2: val_accuracy improved from 0.48462 to 0.68566, saving model to weights-improvement-02-0.6857.hdf5
# 716/716 [==============================] - 29s 40ms/step - loss: 1.2318 - accuracy: 0.5643 - f1_score: 0.5596 - val_loss: 0.9265 - val_accuracy: 0.6857 - val_f1_score: 0.6836
# Epoch 3/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.8562 - accuracy: 0.7033 - f1_score: 0.7002
# Epoch 3: val_accuracy improved from 0.68566 to 0.76259, saving model to weights-improvement-03-0.7626.hdf5
# 716/716 [==============================] - 29s 40ms/step - loss: 0.8561 - accuracy: 0.7033 - f1_score: 0.7002 - val_loss: 0.7063 - val_accuracy: 0.7626 - val_f1_score: 0.7600
# Epoch 4/100
# 714/716 [============================>.] - ETA: 0s - loss: 0.6385 - accuracy: 0.7814 - f1_score: 0.7799
# Epoch 4: val_accuracy improved from 0.76259 to 0.79790, saving model to weights-improvement-04-0.7979.hdf5
# 716/716 [==============================] - 29s 40ms/step - loss: 0.6385 - accuracy: 0.7814 - f1_score: 0.7799 - val_loss: 0.6201 - val_accuracy: 0.7979 - val_f1_score: 0.7960
# Epoch 5/100
# 714/716 [============================>.] - ETA: 0s - loss: 0.4854 - accuracy: 0.8365 - f1_score: 0.8351
# Epoch 5: val_accuracy improved from 0.79790 to 0.82692, saving model to weights-improvement-05-0.8269.hdf5
# 716/716 [==============================] - 29s 40ms/step - loss: 0.4858 - accuracy: 0.8364 - f1_score: 0.8350 - val_loss: 0.5195 - val_accuracy: 0.8269 - val_f1_score: 0.8231
# Epoch 6/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.3784 - accuracy: 0.8711 - f1_score: 0.8705
# Epoch 6: val_accuracy improved from 0.82692 to 0.86364, saving model to weights-improvement-06-0.8636.hdf5
# 716/716 [==============================] - 29s 40ms/step - loss: 0.3783 - accuracy: 0.8711 - f1_score: 0.8705 - val_loss: 0.4250 - val_accuracy: 0.8636 - val_f1_score: 0.8632
# Epoch 7/100
# 714/716 [============================>.] - ETA: 0s - loss: 0.2973 - accuracy: 0.9015 - f1_score: 0.9010
# Epoch 7: val_accuracy improved from 0.86364 to 0.87063, saving model to weights-improvement-07-0.8706.hdf5
# 716/716 [==============================] - 29s 40ms/step - loss: 0.2974 - accuracy: 0.9015 - f1_score: 0.9010 - val_loss: 0.4156 - val_accuracy: 0.8706 - val_f1_score: 0.8690
# Epoch 8/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.2314 - accuracy: 0.9231 - f1_score: 0.9229
# Epoch 8: val_accuracy improved from 0.87063 to 0.88986, saving model to weights-improvement-08-0.8899.hdf5
# 716/716 [==============================] - 29s 40ms/step - loss: 0.2314 - accuracy: 0.9231 - f1_score: 0.9229 - val_loss: 0.3509 - val_accuracy: 0.8899 - val_f1_score: 0.8885
# Epoch 9/100
# 714/716 [============================>.] - ETA: 0s - loss: 0.1908 - accuracy: 0.9381 - f1_score: 0.9379
# Epoch 9: val_accuracy improved from 0.88986 to 0.89580, saving model to weights-improvement-09-0.8958.hdf5
# 716/716 [==============================] - 29s 40ms/step - loss: 0.1906 - accuracy: 0.9382 - f1_score: 0.9380 - val_loss: 0.3405 - val_accuracy: 0.8958 - val_f1_score: 0.8945
# Epoch 10/100
# 714/716 [============================>.] - ETA: 0s - loss: 0.1565 - accuracy: 0.9501 - f1_score: 0.9500
# Epoch 10: val_accuracy did not improve from 0.89580
# 716/716 [==============================] - 29s 40ms/step - loss: 0.1565 - accuracy: 0.9501 - f1_score: 0.9501 - val_loss: 0.3933 - val_accuracy: 0.8794 - val_f1_score: 0.8785
# Epoch 11/100
# 714/716 [============================>.] - ETA: 0s - loss: 0.1374 - accuracy: 0.9544 - f1_score: 0.9543
# Epoch 11: val_accuracy did not improve from 0.89580
# 716/716 [==============================] - 29s 40ms/step - loss: 0.1375 - accuracy: 0.9543 - f1_score: 0.9542 - val_loss: 0.3457 - val_accuracy: 0.8958 - val_f1_score: 0.8956
# Epoch 12/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.1215 - accuracy: 0.9618 - f1_score: 0.9618
# Epoch 12: val_accuracy improved from 0.89580 to 0.91154, saving model to weights-improvement-12-0.9115.hdf5
# 716/716 [==============================] - 29s 40ms/step - loss: 0.1215 - accuracy: 0.9618 - f1_score: 0.9618 - val_loss: 0.3025 - val_accuracy: 0.9115 - val_f1_score: 0.9109
# Epoch 13/100
# 714/716 [============================>.] - ETA: 0s - loss: 0.1038 - accuracy: 0.9664 - f1_score: 0.9664
# Epoch 13: val_accuracy did not improve from 0.91154
# 716/716 [==============================] - 29s 40ms/step - loss: 0.1038 - accuracy: 0.9664 - f1_score: 0.9663 - val_loss: 0.3371 - val_accuracy: 0.9070 - val_f1_score: 0.9065
# Epoch 14/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.0752 - accuracy: 0.9758 - f1_score: 0.9758
# Epoch 14: val_accuracy did not improve from 0.91154
# 716/716 [==============================] - 29s 40ms/step - loss: 0.0751 - accuracy: 0.9758 - f1_score: 0.9758 - val_loss: 0.3212 - val_accuracy: 0.9108 - val_f1_score: 0.9105
# Epoch 15/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.0656 - accuracy: 0.9795 - f1_score: 0.9795
# Epoch 15: val_accuracy improved from 0.91154 to 0.91259, saving model to weights-improvement-15-0.9126.hdf5
# 716/716 [==============================] - 29s 40ms/step - loss: 0.0657 - accuracy: 0.9794 - f1_score: 0.9794 - val_loss: 0.3156 - val_accuracy: 0.9126 - val_f1_score: 0.9117
# Epoch 16/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.0663 - accuracy: 0.9795 - f1_score: 0.9796
# Epoch 16: val_accuracy improved from 0.91259 to 0.91469, saving model to weights-improvement-16-0.9147.hdf5
# 716/716 [==============================] - 29s 40ms/step - loss: 0.0663 - accuracy: 0.9795 - f1_score: 0.9796 - val_loss: 0.3063 - val_accuracy: 0.9147 - val_f1_score: 0.9144
# Epoch 17/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.0532 - accuracy: 0.9835 - f1_score: 0.9835
# Epoch 17: val_accuracy did not improve from 0.91469
# 716/716 [==============================] - 29s 40ms/step - loss: 0.0533 - accuracy: 0.9834 - f1_score: 0.9834 - val_loss: 0.3658 - val_accuracy: 0.9049 - val_f1_score: 0.9058
# Epoch 18/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.0654 - accuracy: 0.9802 - f1_score: 0.9803
# Epoch 18: val_accuracy did not improve from 0.91469
# 716/716 [==============================] - 29s 40ms/step - loss: 0.0654 - accuracy: 0.9802 - f1_score: 0.9803 - val_loss: 0.3540 - val_accuracy: 0.9077 - val_f1_score: 0.9054
# Epoch 19/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.0499 - accuracy: 0.9843 - f1_score: 0.9842
# Epoch 19: val_accuracy improved from 0.91469 to 0.92273, saving model to weights-improvement-19-0.9227.hdf5
# 716/716 [==============================] - 29s 40ms/step - loss: 0.0499 - accuracy: 0.9843 - f1_score: 0.9842 - val_loss: 0.3178 - val_accuracy: 0.9227 - val_f1_score: 0.9220
# Epoch 20/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.0401 - accuracy: 0.9883 - f1_score: 0.9883
# Epoch 20: val_accuracy improved from 0.92273 to 0.93147, saving model to weights-improvement-20-0.9315.hdf5
# 716/716 [==============================] - 29s 40ms/step - loss: 0.0401 - accuracy: 0.9883 - f1_score: 0.9883 - val_loss: 0.2940 - val_accuracy: 0.9315 - val_f1_score: 0.9310
# Epoch 21/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.0350 - accuracy: 0.9901 - f1_score: 0.9902
# Epoch 21: val_accuracy did not improve from 0.93147
# 716/716 [==============================] - 29s 40ms/step - loss: 0.0350 - accuracy: 0.9901 - f1_score: 0.9902 - val_loss: 0.3127 - val_accuracy: 0.9245 - val_f1_score: 0.9240
# Epoch 22/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.0277 - accuracy: 0.9916 - f1_score: 0.9916
# Epoch 22: val_accuracy did not improve from 0.93147
# 716/716 [==============================] - 29s 40ms/step - loss: 0.0277 - accuracy: 0.9916 - f1_score: 0.9916 - val_loss: 0.3089 - val_accuracy: 0.9287 - val_f1_score: 0.9276
# Epoch 23/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.0358 - accuracy: 0.9893 - f1_score: 0.9894
# Epoch 23: val_accuracy improved from 0.93147 to 0.93287, saving model to weights-improvement-23-0.9329.hdf5
# 716/716 [==============================] - 29s 40ms/step - loss: 0.0358 - accuracy: 0.9893 - f1_score: 0.9894 - val_loss: 0.2807 - val_accuracy: 0.9329 - val_f1_score: 0.9327
# Epoch 24/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.0263 - accuracy: 0.9928 - f1_score: 0.9928
# Epoch 24: val_accuracy improved from 0.93287 to 0.93392, saving model to weights-improvement-24-0.9339.hdf5
# 716/716 [==============================] - 29s 40ms/step - loss: 0.0263 - accuracy: 0.9928 - f1_score: 0.9928 - val_loss: 0.2915 - val_accuracy: 0.9339 - val_f1_score: 0.9335
# Epoch 25/100
# 714/716 [============================>.] - ETA: 0s - loss: 0.0287 - accuracy: 0.9915 - f1_score: 0.9914
# Epoch 25: val_accuracy did not improve from 0.93392
# 716/716 [==============================] - 29s 40ms/step - loss: 0.0287 - accuracy: 0.9915 - f1_score: 0.9914 - val_loss: 0.3687 - val_accuracy: 0.9108 - val_f1_score: 0.9105
# Epoch 26/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.0234 - accuracy: 0.9934 - f1_score: 0.9935
# Epoch 26: val_accuracy did not improve from 0.93392
# 716/716 [==============================] - 29s 40ms/step - loss: 0.0234 - accuracy: 0.9934 - f1_score: 0.9935 - val_loss: 0.3325 - val_accuracy: 0.9308 - val_f1_score: 0.9296
# Epoch 27/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.0285 - accuracy: 0.9917 - f1_score: 0.9916
# Epoch 27: val_accuracy did not improve from 0.93392
# 716/716 [==============================] - 29s 40ms/step - loss: 0.0285 - accuracy: 0.9917 - f1_score: 0.9916 - val_loss: 0.3148 - val_accuracy: 0.9276 - val_f1_score: 0.9274
# Epoch 28/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.0210 - accuracy: 0.9952 - f1_score: 0.9952
# Epoch 28: val_accuracy did not improve from 0.93392
# 716/716 [==============================] - 29s 40ms/step - loss: 0.0210 - accuracy: 0.9952 - f1_score: 0.9952 - val_loss: 0.3028 - val_accuracy: 0.9297 - val_f1_score: 0.9285
# Epoch 29/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.0227 - accuracy: 0.9940 - f1_score: 0.9940
# Epoch 29: val_accuracy did not improve from 0.93392
# 716/716 [==============================] - 29s 40ms/step - loss: 0.0227 - accuracy: 0.9940 - f1_score: 0.9940 - val_loss: 0.3159 - val_accuracy: 0.9339 - val_f1_score: 0.9335

# %%
model.evaluate(test_data, batch_size= 16, return_dict= True)
# Out:
# 94/94 [==============================] - 254s 3s/step - loss: 0.3586 - accuracy: 0.9387 - f1_score: 0.9384
# {'loss': 0.35859131813049316,
#  'accuracy': 0.9386666417121887,
#  'f1_score': 0.9384477734565735}

# %%
# Generating Confusion Matrix and Classification Report
Y_pred= model.predict_generator(test_data, 1500// 16 + 1)
y_pred= np.argmax(Y_pred, axis= 1)
print('Confusion Matrix')
conf_matrix= confusion_matrix(test_data.classes, y_pred)
conf_mat = np.array2string(conf_matrix)
#print(conf_matrix)
#print("=============================================================================================")
print('Classification Report')
target_names= test_data.class_indices
class_rep_vgg = classification_report(test_data.classes, y_pred, target_names=target_names)
print(class_rep_vgg)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
# Confusion Matrix
# Classification Report
#                           precision    recall  f1-score   support
#
#    bacterial_leaf_blight       0.94      0.88      0.91       150
#    bacterial_leaf_streak       0.95      0.97      0.96       150
# bacterial_panicle_blight       0.99      0.91      0.94       150
#                    blast       0.91      0.97      0.94       150
#               brown_spot       0.93      0.91      0.92       150
#               dead_heart       0.90      1.00      0.95       150
#             downy_mildew       0.96      0.89      0.93       150
#                    hispa       0.95      0.93      0.94       150
#                   normal       0.95      0.95      0.95       150
#                   tungro       0.92      0.97      0.94       150
#
#                 accuracy                           0.94      1500
#                macro avg       0.94      0.94      0.94      1500
#             weighted avg       0.94      0.94      0.94      1500

# %%
ConfusionMatrixDisplay.from_predictions(test_data.classes, y_pred, display_labels= target_names, xticks_rotation= 'vertical')
