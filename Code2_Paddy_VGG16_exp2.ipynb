# %% [markdown]
# <a href="https://colab.research.google.com/github/anikch/paddy/blob/main/Code2_Paddy_VGG16_exp2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow_addons
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow_addons
#   Downloading tensorflow_addons-0.18.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 4.9 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tensorflow_addons) (21.3)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow_addons) (2.7.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tensorflow_addons) (3.0.9)
# Installing collected packages: tensorflow-addons
# Successfully installed tensorflow-addons-0.18.0

# %%
# !pip install keras_cv
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting keras_cv
#   Downloading keras_cv-0.3.4-py3-none-any.whl (394 kB)
#      |████████████████████████████████| 394 kB 4.9 MB/s
# Requirement already satisfied: absl-py in /usr/local/lib/python3.7/dist-packages (from keras_cv) (1.3.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from keras_cv) (2022.6.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from keras_cv) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->keras_cv) (3.0.9)
# Installing collected packages: keras-cv
# Successfully installed keras-cv-0.3.4

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import tensorflow_addons as tfa
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import seaborn as sns
from typing import List
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from functools import partial
import posixpath
from keras import models, regularizers, layers, optimizers, losses, metrics
import keras_cv
from keras.models import Sequential
from keras.layers import Dense
from tensorflow.keras.utils import plot_model

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !nvidia-smi
# Out:
# Mon Oct 24 20:35:03 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  A100-SXM4-40GB      Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   29C    P0    46W / 400W |      0MiB / 40536MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
colab= '/content/drive/MyDrive'
local= r'G:\My Drive'

code_runtime= colab

# %%
tf.__version__
# Out:
# '2.9.2'

# %%
file1= 'thesis/dataset/paddy_doctor/train.csv'
inp_file = posixpath.join(code_runtime, file1)

train_table=pd.read_csv(inp_file)
train_table
# Out:
#          image_id                  label variety  age
# 0      100330.jpg  bacterial_leaf_blight   ADT45   45
# 1      100365.jpg  bacterial_leaf_blight   ADT45   45
# 2      100382.jpg  bacterial_leaf_blight   ADT45   45
# 3      100632.jpg  bacterial_leaf_blight   ADT45   45
# 4      101918.jpg  bacterial_leaf_blight   ADT45   45
# ...           ...                    ...     ...  ...
# 10402  107607.jpg                 tungro   Zonal   55
# 10403  107811.jpg                 tungro   Zonal   55
# 10404  108547.jpg                 tungro   Zonal   55
# 10405  110245.jpg                 tungro   Zonal   55
# 10406  110381.jpg                 tungro   Zonal   55
#
# [10407 rows x 4 columns]

# %%
labels=list(np.unique(train_table['label']))
labels
# Out:
# ['bacterial_leaf_blight',
#  'bacterial_leaf_streak',
#  'bacterial_panicle_blight',
#  'blast',
#  'brown_spot',
#  'dead_heart',
#  'downy_mildew',
#  'hispa',
#  'normal',
#  'tungro']

# %%
train_dir= 'thesis/dataset/paddy_doctor/train/'
val_dir= 'thesis/dataset/paddy_doctor/val/'
img_size= 224

train_files= posixpath.join(code_runtime, train_dir)
test_files= posixpath.join(code_runtime, val_dir)

train_data= tf.keras.utils.image_dataset_from_directory(train_files,
                                                        labels='inferred',
                                                        label_mode='categorical',
                                                        validation_split=0.2,
                                                        subset="training",
                                                        class_names=labels,
                                                        color_mode='rgb',
                                                        image_size=(img_size, img_size),
                                                        shuffle=True,
                                                        seed= 42,
                                                        batch_size= 16)

val_data= tf.keras.utils.image_dataset_from_directory(train_files,
                                                        labels= 'inferred',
                                                        label_mode='categorical',
                                                        validation_split=0.2,
                                                        subset="validation",
                                                        class_names= labels,
                                                        color_mode='rgb',
                                                        image_size=(img_size, img_size),
                                                        shuffle=True,
                                                        seed= 42,
                                                        batch_size= 16)


test_datagen= ImageDataGenerator()
test_data= test_datagen.flow_from_directory(test_files,
                                            target_size= (img_size, img_size),
                                            batch_size= 16,
                                            shuffle = False, 
                                            class_mode='categorical')
# Out:
# Found 14302 files belonging to 10 classes.
# Using 11442 files for training.
# Found 14302 files belonging to 10 classes.
# Using 2860 files for validation.
# Found 1500 images belonging to 10 classes.

# %%
class_names = train_data.class_names
print(class_names)
# Out:
# ['bacterial_leaf_blight', 'bacterial_leaf_streak', 'bacterial_panicle_blight', 'blast', 'brown_spot', 'dead_heart', 'downy_mildew', 'hispa', 'normal', 'tungro']

# %%
test_data.class_indices
# Out:
# {'bacterial_leaf_blight': 0,
#  'bacterial_leaf_streak': 1,
#  'bacterial_panicle_blight': 2,
#  'blast': 3,
#  'brown_spot': 4,
#  'dead_heart': 5,
#  'downy_mildew': 6,
#  'hispa': 7,
#  'normal': 8,
#  'tungro': 9}

# %% [markdown]
# ## VGG16 (No Augmentation + Transfer Learning + Fine Tune)

# %%
base_model= tf.keras.applications.VGG16(
    include_top= False,
    weights= 'imagenet',
    input_shape=(img_size, img_size, 3),
    pooling= 'max'
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step

# %%
tf.keras.utils.plot_model(
    base_model,
    show_shapes= True,
    show_dtype=False,
    show_layer_names=True,
    rankdir="TR",
    expand_nested=False,
    dpi=72,
    layer_range=None,
    show_layer_activations=True,
)

# %%
inputs= tf.keras.Input(shape= (img_size, img_size, 3))
preprocess_layer= tf.keras.applications.vgg16.preprocess_input(inputs)
normalization_layer= tf.keras.layers.Rescaling(scale= 1./127.5, offset= -1)(preprocess_layer)
x= base_model(normalization_layer)
x= tf.keras.layers.Dropout(0.25)(x)
outputs= tf.keras.layers.Dense(10, activation= 'softmax')(x)

# %%
model= tf.keras.Model(inputs= inputs, outputs= outputs, name= "vgg16_TL_no_augmentation")

# %%
model.summary()
# Out:
# Model: "vgg16_TL_no_augmentation"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem (S  (None, 224, 224, 3)      0
#  licingOpLambda)
#
#  tf.nn.bias_add (TFOpLambda)  (None, 224, 224, 3)      0
#
#  rescaling (Rescaling)       (None, 224, 224, 3)       0
#
#  vgg16 (Functional)          (None, 512)               14714688
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense (Dense)               (None, 10)                5130
#
# =================================================================
# Total params: 14,719,818
# Trainable params: 14,719,818
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(
    model,
    show_shapes= True,
    show_dtype=False,
    show_layer_names=True,
    rankdir="TR",
    expand_nested=False,
    dpi=72,
    layer_range=None,
    show_layer_activations=True,
)

# %%
# %%time
n_epochs= 100

filepath= "weights-improvement-{epoch:02d}-{val_accuracy:.4f}.hdf5"
checkpoint_callback= ModelCheckpoint(filepath, monitor= 'val_accuracy', verbose= 1, save_best_only= True, mode= 'max')
early_stop_callback= EarlyStopping(monitor='val_accuracy', patience= 5, verbose= False, mode='max')
callbacks_list=[checkpoint_callback, early_stop_callback]
# Out:
# CPU times: user 76 µs, sys: 38 µs, total: 114 µs
# Wall time: 118 µs

# %%
optimizer_adam_amsgrad= tf.keras.optimizers.Adam(learning_rate= 1e-4, amsgrad= True)
optimizer_adam= tf.keras.optimizers.Adam(learning_rate= 1e-4, amsgrad= False)
optimizer_sgd= tf.keras.optimizers.SGD(lr=1e-4, momentum= 0.9)

# %%
model.compile(
        optimizer = optimizer_sgd,
        loss = 'categorical_crossentropy', 
        metrics = ['accuracy', tfa.metrics.F1Score(average='macro', num_classes= 10)]
        )

# %%
history= model.fit(train_data,
                  epochs= n_epochs,
                  validation_data= val_data,
                  callbacks= callbacks_list,
                  verbose= 1)
# Out:
# Epoch 1/100
# 716/716 [==============================] - ETA: 0s - loss: 1.8665 - accuracy: 0.3288 - f1_score: 0.3267
# Epoch 1: val_accuracy improved from -inf to 0.51643, saving model to weights-improvement-01-0.5164.hdf5
# 716/716 [==============================] - 303s 403ms/step - loss: 1.8665 - accuracy: 0.3288 - f1_score: 0.3267 - val_loss: 1.3630 - val_accuracy: 0.5164 - val_f1_score: 0.5083
# Epoch 2/100
# 715/716 [============================>.] - ETA: 0s - loss: 1.1701 - accuracy: 0.5920 - f1_score: 0.5895
# Epoch 2: val_accuracy improved from 0.51643 to 0.68217, saving model to weights-improvement-02-0.6822.hdf5
# 716/716 [==============================] - 32s 44ms/step - loss: 1.1706 - accuracy: 0.5919 - f1_score: 0.5894 - val_loss: 0.9420 - val_accuracy: 0.6822 - val_f1_score: 0.6790
# Epoch 3/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.8184 - accuracy: 0.7191 - f1_score: 0.7165
# Epoch 3: val_accuracy improved from 0.68217 to 0.78357, saving model to weights-improvement-03-0.7836.hdf5
# 716/716 [==============================] - 32s 44ms/step - loss: 0.8183 - accuracy: 0.7190 - f1_score: 0.7165 - val_loss: 0.6707 - val_accuracy: 0.7836 - val_f1_score: 0.7794
# Epoch 4/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.5995 - accuracy: 0.7971 - f1_score: 0.7952
# Epoch 4: val_accuracy improved from 0.78357 to 0.81399, saving model to weights-improvement-04-0.8140.hdf5
# 716/716 [==============================] - 32s 44ms/step - loss: 0.5997 - accuracy: 0.7971 - f1_score: 0.7952 - val_loss: 0.5662 - val_accuracy: 0.8140 - val_f1_score: 0.8148
# Epoch 5/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.4500 - accuracy: 0.8470 - f1_score: 0.8458
# Epoch 5: val_accuracy improved from 0.81399 to 0.86084, saving model to weights-improvement-05-0.8608.hdf5
# 716/716 [==============================] - 32s 44ms/step - loss: 0.4500 - accuracy: 0.8471 - f1_score: 0.8458 - val_loss: 0.4507 - val_accuracy: 0.8608 - val_f1_score: 0.8616
# Epoch 6/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.3350 - accuracy: 0.8900 - f1_score: 0.8893
# Epoch 6: val_accuracy did not improve from 0.86084
# 716/716 [==============================] - 32s 44ms/step - loss: 0.3350 - accuracy: 0.8901 - f1_score: 0.8893 - val_loss: 0.4431 - val_accuracy: 0.8497 - val_f1_score: 0.8508
# Epoch 7/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.2609 - accuracy: 0.9142 - f1_score: 0.9137
# Epoch 7: val_accuracy improved from 0.86084 to 0.88462, saving model to weights-improvement-07-0.8846.hdf5
# 716/716 [==============================] - 32s 44ms/step - loss: 0.2608 - accuracy: 0.9143 - f1_score: 0.9138 - val_loss: 0.3808 - val_accuracy: 0.8846 - val_f1_score: 0.8826
# Epoch 8/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.2024 - accuracy: 0.9335 - f1_score: 0.9333
# Epoch 8: val_accuracy improved from 0.88462 to 0.89965, saving model to weights-improvement-08-0.8997.hdf5
# 716/716 [==============================] - 32s 44ms/step - loss: 0.2024 - accuracy: 0.9335 - f1_score: 0.9333 - val_loss: 0.3573 - val_accuracy: 0.8997 - val_f1_score: 0.8974
# Epoch 9/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.1594 - accuracy: 0.9485 - f1_score: 0.9483
# Epoch 9: val_accuracy improved from 0.89965 to 0.90559, saving model to weights-improvement-09-0.9056.hdf5
# 716/716 [==============================] - 32s 44ms/step - loss: 0.1594 - accuracy: 0.9485 - f1_score: 0.9483 - val_loss: 0.3249 - val_accuracy: 0.9056 - val_f1_score: 0.9054
# Epoch 10/100
# 714/716 [============================>.] - ETA: 0s - loss: 0.1315 - accuracy: 0.9577 - f1_score: 0.9576
# Epoch 10: val_accuracy did not improve from 0.90559
# 716/716 [==============================] - 32s 45ms/step - loss: 0.1315 - accuracy: 0.9577 - f1_score: 0.9576 - val_loss: 0.3740 - val_accuracy: 0.8983 - val_f1_score: 0.8977
# Epoch 11/100
# 714/716 [============================>.] - ETA: 0s - loss: 0.1148 - accuracy: 0.9629 - f1_score: 0.9628
# Epoch 11: val_accuracy improved from 0.90559 to 0.90979, saving model to weights-improvement-11-0.9098.hdf5
# 716/716 [==============================] - 32s 44ms/step - loss: 0.1147 - accuracy: 0.9629 - f1_score: 0.9628 - val_loss: 0.3181 - val_accuracy: 0.9098 - val_f1_score: 0.9086
# Epoch 12/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.0989 - accuracy: 0.9698 - f1_score: 0.9696
# Epoch 12: val_accuracy did not improve from 0.90979
# 716/716 [==============================] - 32s 44ms/step - loss: 0.0989 - accuracy: 0.9698 - f1_score: 0.9696 - val_loss: 0.3551 - val_accuracy: 0.8993 - val_f1_score: 0.8990
# Epoch 13/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.0869 - accuracy: 0.9705 - f1_score: 0.9703
# Epoch 13: val_accuracy improved from 0.90979 to 0.91608, saving model to weights-improvement-13-0.9161.hdf5
# 716/716 [==============================] - 32s 45ms/step - loss: 0.0870 - accuracy: 0.9705 - f1_score: 0.9702 - val_loss: 0.3417 - val_accuracy: 0.9161 - val_f1_score: 0.9145
# Epoch 14/100
# 716/716 [==============================] - ETA: 0s - loss: 0.0746 - accuracy: 0.9761 - f1_score: 0.9759
# Epoch 14: val_accuracy did not improve from 0.91608
# 716/716 [==============================] - 32s 44ms/step - loss: 0.0746 - accuracy: 0.9761 - f1_score: 0.9759 - val_loss: 0.3582 - val_accuracy: 0.9087 - val_f1_score: 0.9090
# Epoch 15/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.0645 - accuracy: 0.9814 - f1_score: 0.9813
# Epoch 15: val_accuracy improved from 0.91608 to 0.92238, saving model to weights-improvement-15-0.9224.hdf5
# 716/716 [==============================] - 32s 44ms/step - loss: 0.0645 - accuracy: 0.9814 - f1_score: 0.9813 - val_loss: 0.3116 - val_accuracy: 0.9224 - val_f1_score: 0.9219
# Epoch 16/100
# 714/716 [============================>.] - ETA: 0s - loss: 0.0600 - accuracy: 0.9803 - f1_score: 0.9802
# Epoch 16: val_accuracy did not improve from 0.92238
# 716/716 [==============================] - 32s 44ms/step - loss: 0.0599 - accuracy: 0.9803 - f1_score: 0.9802 - val_loss: 0.3774 - val_accuracy: 0.8983 - val_f1_score: 0.8989
# Epoch 17/100
# 714/716 [============================>.] - ETA: 0s - loss: 0.0493 - accuracy: 0.9846 - f1_score: 0.9846
# Epoch 17: val_accuracy improved from 0.92238 to 0.92413, saving model to weights-improvement-17-0.9241.hdf5
# 716/716 [==============================] - 32s 45ms/step - loss: 0.0493 - accuracy: 0.9846 - f1_score: 0.9846 - val_loss: 0.3002 - val_accuracy: 0.9241 - val_f1_score: 0.9238
# Epoch 18/100
# 714/716 [============================>.] - ETA: 0s - loss: 0.0437 - accuracy: 0.9865 - f1_score: 0.9865
# Epoch 18: val_accuracy improved from 0.92413 to 0.92692, saving model to weights-improvement-18-0.9269.hdf5
# 716/716 [==============================] - 32s 45ms/step - loss: 0.0438 - accuracy: 0.9865 - f1_score: 0.9865 - val_loss: 0.3209 - val_accuracy: 0.9269 - val_f1_score: 0.9263
# Epoch 19/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.0343 - accuracy: 0.9888 - f1_score: 0.9888
# Epoch 19: val_accuracy did not improve from 0.92692
# 716/716 [==============================] - 32s 44ms/step - loss: 0.0343 - accuracy: 0.9888 - f1_score: 0.9888 - val_loss: 0.3155 - val_accuracy: 0.9227 - val_f1_score: 0.9225
# Epoch 20/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.0307 - accuracy: 0.9915 - f1_score: 0.9916
# Epoch 20: val_accuracy did not improve from 0.92692
# 716/716 [==============================] - 32s 44ms/step - loss: 0.0307 - accuracy: 0.9915 - f1_score: 0.9916 - val_loss: 0.3484 - val_accuracy: 0.9227 - val_f1_score: 0.9225
# Epoch 21/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.0290 - accuracy: 0.9917 - f1_score: 0.9917
# Epoch 21: val_accuracy improved from 0.92692 to 0.92937, saving model to weights-improvement-21-0.9294.hdf5
# 716/716 [==============================] - 32s 44ms/step - loss: 0.0290 - accuracy: 0.9917 - f1_score: 0.9917 - val_loss: 0.3102 - val_accuracy: 0.9294 - val_f1_score: 0.9288
# Epoch 22/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.0275 - accuracy: 0.9913 - f1_score: 0.9914
# Epoch 22: val_accuracy did not improve from 0.92937
# 716/716 [==============================] - 32s 44ms/step - loss: 0.0275 - accuracy: 0.9913 - f1_score: 0.9914 - val_loss: 0.3009 - val_accuracy: 0.9245 - val_f1_score: 0.9236
# Epoch 23/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.0357 - accuracy: 0.9904 - f1_score: 0.9904
# Epoch 23: val_accuracy improved from 0.92937 to 0.93042, saving model to weights-improvement-23-0.9304.hdf5
# 716/716 [==============================] - 32s 45ms/step - loss: 0.0357 - accuracy: 0.9904 - f1_score: 0.9904 - val_loss: 0.3189 - val_accuracy: 0.9304 - val_f1_score: 0.9296
# Epoch 24/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.0276 - accuracy: 0.9919 - f1_score: 0.9919
# Epoch 24: val_accuracy did not improve from 0.93042
# 716/716 [==============================] - 32s 44ms/step - loss: 0.0276 - accuracy: 0.9919 - f1_score: 0.9919 - val_loss: 0.3493 - val_accuracy: 0.9185 - val_f1_score: 0.9179
# Epoch 25/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.0185 - accuracy: 0.9951 - f1_score: 0.9951
# Epoch 25: val_accuracy improved from 0.93042 to 0.93497, saving model to weights-improvement-25-0.9350.hdf5
# 716/716 [==============================] - 32s 44ms/step - loss: 0.0185 - accuracy: 0.9951 - f1_score: 0.9951 - val_loss: 0.2800 - val_accuracy: 0.9350 - val_f1_score: 0.9346
# Epoch 26/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.0191 - accuracy: 0.9944 - f1_score: 0.9944
# Epoch 26: val_accuracy did not improve from 0.93497
# 716/716 [==============================] - 32s 44ms/step - loss: 0.0191 - accuracy: 0.9944 - f1_score: 0.9944 - val_loss: 0.3386 - val_accuracy: 0.9248 - val_f1_score: 0.9240
# Epoch 27/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.0381 - accuracy: 0.9892 - f1_score: 0.9892
# Epoch 27: val_accuracy did not improve from 0.93497
# 716/716 [==============================] - 32s 44ms/step - loss: 0.0381 - accuracy: 0.9892 - f1_score: 0.9892 - val_loss: 0.3591 - val_accuracy: 0.9203 - val_f1_score: 0.9199
# Epoch 28/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.0233 - accuracy: 0.9929 - f1_score: 0.9929
# Epoch 28: val_accuracy did not improve from 0.93497
# 716/716 [==============================] - 32s 44ms/step - loss: 0.0233 - accuracy: 0.9929 - f1_score: 0.9929 - val_loss: 0.3019 - val_accuracy: 0.9336 - val_f1_score: 0.9327
# Epoch 29/100
# 716/716 [==============================] - ETA: 0s - loss: 0.0198 - accuracy: 0.9935 - f1_score: 0.9935
# Epoch 29: val_accuracy did not improve from 0.93497
# 716/716 [==============================] - 32s 44ms/step - loss: 0.0198 - accuracy: 0.9935 - f1_score: 0.9935 - val_loss: 0.3562 - val_accuracy: 0.9231 - val_f1_score: 0.9214
# Epoch 30/100
# 714/716 [============================>.] - ETA: 0s - loss: 0.0119 - accuracy: 0.9964 - f1_score: 0.9964
# Epoch 30: val_accuracy improved from 0.93497 to 0.93531, saving model to weights-improvement-30-0.9353.hdf5
# 716/716 [==============================] - 32s 45ms/step - loss: 0.0119 - accuracy: 0.9964 - f1_score: 0.9964 - val_loss: 0.3107 - val_accuracy: 0.9353 - val_f1_score: 0.9346
# Epoch 31/100
# 716/716 [==============================] - ETA: 0s - loss: 0.0139 - accuracy: 0.9958 - f1_score: 0.9958
# Epoch 31: val_accuracy did not improve from 0.93531
# 716/716 [==============================] - 32s 44ms/step - loss: 0.0139 - accuracy: 0.9958 - f1_score: 0.9958 - val_loss: 0.2930 - val_accuracy: 0.9325 - val_f1_score: 0.9314
# Epoch 32/100
# 714/716 [============================>.] - ETA: 0s - loss: 0.0148 - accuracy: 0.9954 - f1_score: 0.9954
# Epoch 32: val_accuracy did not improve from 0.93531
# 716/716 [==============================] - 32s 44ms/step - loss: 0.0149 - accuracy: 0.9954 - f1_score: 0.9953 - val_loss: 0.2866 - val_accuracy: 0.9332 - val_f1_score: 0.9324
# Epoch 33/100
# 716/716 [==============================] - ETA: 0s - loss: 0.0168 - accuracy: 0.9955 - f1_score: 0.9955
# Epoch 33: val_accuracy improved from 0.93531 to 0.93741, saving model to weights-improvement-33-0.9374.hdf5
# 716/716 [==============================] - 32s 45ms/step - loss: 0.0168 - accuracy: 0.9955 - f1_score: 0.9955 - val_loss: 0.3045 - val_accuracy: 0.9374 - val_f1_score: 0.9362
# Epoch 34/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.0135 - accuracy: 0.9965 - f1_score: 0.9965
# Epoch 34: val_accuracy improved from 0.93741 to 0.93916, saving model to weights-improvement-34-0.9392.hdf5
# 716/716 [==============================] - 32s 44ms/step - loss: 0.0135 - accuracy: 0.9965 - f1_score: 0.9965 - val_loss: 0.2958 - val_accuracy: 0.9392 - val_f1_score: 0.9381
# Epoch 35/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.0100 - accuracy: 0.9972 - f1_score: 0.9972
# Epoch 35: val_accuracy improved from 0.93916 to 0.93986, saving model to weights-improvement-35-0.9399.hdf5
# 716/716 [==============================] - 32s 44ms/step - loss: 0.0100 - accuracy: 0.9972 - f1_score: 0.9972 - val_loss: 0.3142 - val_accuracy: 0.9399 - val_f1_score: 0.9393
# Epoch 36/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.0097 - accuracy: 0.9973 - f1_score: 0.9973
# Epoch 36: val_accuracy did not improve from 0.93986
# 716/716 [==============================] - 32s 44ms/step - loss: 0.0097 - accuracy: 0.9973 - f1_score: 0.9973 - val_loss: 0.3213 - val_accuracy: 0.9290 - val_f1_score: 0.9291
# Epoch 37/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.0088 - accuracy: 0.9974 - f1_score: 0.9974
# Epoch 37: val_accuracy improved from 0.93986 to 0.94126, saving model to weights-improvement-37-0.9413.hdf5
# 716/716 [==============================] - 32s 44ms/step - loss: 0.0088 - accuracy: 0.9974 - f1_score: 0.9974 - val_loss: 0.3383 - val_accuracy: 0.9413 - val_f1_score: 0.9405
# Epoch 38/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.0086 - accuracy: 0.9976 - f1_score: 0.9976
# Epoch 38: val_accuracy did not improve from 0.94126
# 716/716 [==============================] - 32s 44ms/step - loss: 0.0086 - accuracy: 0.9976 - f1_score: 0.9976 - val_loss: 0.3685 - val_accuracy: 0.9241 - val_f1_score: 0.9240
# Epoch 39/100
# 714/716 [============================>.] - ETA: 0s - loss: 0.0148 - accuracy: 0.9958 - f1_score: 0.9958
# Epoch 39: val_accuracy did not improve from 0.94126
# 716/716 [==============================] - 32s 44ms/step - loss: 0.0148 - accuracy: 0.9958 - f1_score: 0.9958 - val_loss: 0.3266 - val_accuracy: 0.9371 - val_f1_score: 0.9366
# Epoch 40/100
# 716/716 [==============================] - ETA: 0s - loss: 0.0101 - accuracy: 0.9975 - f1_score: 0.9975
# Epoch 40: val_accuracy did not improve from 0.94126
# 716/716 [==============================] - 32s 44ms/step - loss: 0.0101 - accuracy: 0.9975 - f1_score: 0.9975 - val_loss: 0.3296 - val_accuracy: 0.9360 - val_f1_score: 0.9353
# Epoch 41/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.0103 - accuracy: 0.9969 - f1_score: 0.9969
# Epoch 41: val_accuracy did not improve from 0.94126
# 716/716 [==============================] - 32s 44ms/step - loss: 0.0103 - accuracy: 0.9969 - f1_score: 0.9969 - val_loss: 0.2867 - val_accuracy: 0.9392 - val_f1_score: 0.9384
# Epoch 42/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.0036 - accuracy: 0.9991 - f1_score: 0.9991
# Epoch 42: val_accuracy improved from 0.94126 to 0.94650, saving model to weights-improvement-42-0.9465.hdf5
# 716/716 [==============================] - 32s 45ms/step - loss: 0.0036 - accuracy: 0.9991 - f1_score: 0.9991 - val_loss: 0.2877 - val_accuracy: 0.9465 - val_f1_score: 0.9458
# Epoch 43/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.0042 - accuracy: 0.9986 - f1_score: 0.9986
# Epoch 43: val_accuracy did not improve from 0.94650
# 716/716 [==============================] - 32s 44ms/step - loss: 0.0042 - accuracy: 0.9986 - f1_score: 0.9986 - val_loss: 0.3025 - val_accuracy: 0.9402 - val_f1_score: 0.9396
# Epoch 44/100
# 714/716 [============================>.] - ETA: 0s - loss: 0.0109 - accuracy: 0.9971 - f1_score: 0.9971
# Epoch 44: val_accuracy did not improve from 0.94650
# 716/716 [==============================] - 32s 44ms/step - loss: 0.0109 - accuracy: 0.9971 - f1_score: 0.9971 - val_loss: 0.2869 - val_accuracy: 0.9462 - val_f1_score: 0.9452
# Epoch 45/100
# 714/716 [============================>.] - ETA: 0s - loss: 0.0106 - accuracy: 0.9969 - f1_score: 0.9969
# Epoch 45: val_accuracy did not improve from 0.94650
# 716/716 [==============================] - 32s 44ms/step - loss: 0.0105 - accuracy: 0.9969 - f1_score: 0.9969 - val_loss: 0.3724 - val_accuracy: 0.9283 - val_f1_score: 0.9272
# Epoch 46/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.0090 - accuracy: 0.9974 - f1_score: 0.9974
# Epoch 46: val_accuracy did not improve from 0.94650
# 716/716 [==============================] - 32s 44ms/step - loss: 0.0090 - accuracy: 0.9974 - f1_score: 0.9974 - val_loss: 0.2865 - val_accuracy: 0.9416 - val_f1_score: 0.9408
# Epoch 47/100
# 716/716 [==============================] - ETA: 0s - loss: 0.0035 - accuracy: 0.9992 - f1_score: 0.9992
# Epoch 47: val_accuracy did not improve from 0.94650
# 716/716 [==============================] - 32s 44ms/step - loss: 0.0035 - accuracy: 0.9992 - f1_score: 0.9992 - val_loss: 0.3023 - val_accuracy: 0.9430 - val_f1_score: 0.9426

# %%
model.evaluate(test_data, batch_size= 16, return_dict= True)
# Out:
# 94/94 [==============================] - 329s 4s/step - loss: 0.3138 - accuracy: 0.9453 - f1_score: 0.9453
# {'loss': 0.31376567482948303,
#  'accuracy': 0.9453333616256714,
#  'f1_score': 0.9452508091926575}

# %%
# Generating Confusion Matrix and Classification Report
Y_pred= model.predict_generator(test_data, 1500// 16 + 1)
y_pred= np.argmax(Y_pred, axis= 1)
print('Confusion Matrix')
conf_matrix= confusion_matrix(test_data.classes, y_pred)
conf_mat = np.array2string(conf_matrix)
#print(conf_matrix)
#print("=============================================================================================")
print('Classification Report')
target_names= test_data.class_indices
class_rep_vgg = classification_report(test_data.classes, y_pred, target_names=target_names)
print(class_rep_vgg)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
# Confusion Matrix
# Classification Report
#                           precision    recall  f1-score   support
#
#    bacterial_leaf_blight       0.94      0.89      0.91       150
#    bacterial_leaf_streak       0.96      0.95      0.95       150
# bacterial_panicle_blight       0.99      0.95      0.97       150
#                    blast       0.93      0.97      0.95       150
#               brown_spot       0.92      0.95      0.93       150
#               dead_heart       0.96      0.99      0.97       150
#             downy_mildew       0.95      0.90      0.92       150
#                    hispa       0.97      0.94      0.96       150
#                   normal       0.94      0.95      0.94       150
#                   tungro       0.91      0.96      0.94       150
#
#                 accuracy                           0.95      1500
#                macro avg       0.95      0.95      0.95      1500
#             weighted avg       0.95      0.95      0.95      1500

# %%
ConfusionMatrixDisplay.from_predictions(test_data.classes, y_pred, display_labels= target_names, xticks_rotation= 'vertical')
