# %% [markdown]
# <a href="https://colab.research.google.com/github/anikch/paddy/blob/main/Code2_Paddy_VGG16_exp2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow_addons
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflow_addons in /usr/local/lib/python3.7/dist-packages (0.18.0)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow_addons) (2.7.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tensorflow_addons) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tensorflow_addons) (3.0.9)

# %%
# !pip install keras_cv
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: keras_cv in /usr/local/lib/python3.7/dist-packages (0.3.4)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from keras_cv) (2022.6.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.7/dist-packages (from keras_cv) (1.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from keras_cv) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->keras_cv) (3.0.9)

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import tensorflow_addons as tfa
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import seaborn as sns
from typing import List
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from functools import partial
import posixpath
from keras import models, regularizers, layers, optimizers, losses, metrics
import keras_cv
from keras.models import Sequential
from keras.layers import Dense
from tensorflow.keras.utils import plot_model

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !nvidia-smi
# Out:
# Mon Oct 24 19:06:11 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  A100-SXM4-40GB      Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0    46W / 400W |      0MiB / 40536MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
colab= '/content/drive/MyDrive'
local= r'G:\My Drive'

code_runtime= colab

# %%
tf.__version__
# Out:
# '2.9.2'

# %%
file1= 'thesis/dataset/paddy_doctor/train.csv'
inp_file = posixpath.join(code_runtime, file1)

train_table=pd.read_csv(inp_file)
train_table
# Out:
#          image_id                  label variety  age
# 0      100330.jpg  bacterial_leaf_blight   ADT45   45
# 1      100365.jpg  bacterial_leaf_blight   ADT45   45
# 2      100382.jpg  bacterial_leaf_blight   ADT45   45
# 3      100632.jpg  bacterial_leaf_blight   ADT45   45
# 4      101918.jpg  bacterial_leaf_blight   ADT45   45
# ...           ...                    ...     ...  ...
# 10402  107607.jpg                 tungro   Zonal   55
# 10403  107811.jpg                 tungro   Zonal   55
# 10404  108547.jpg                 tungro   Zonal   55
# 10405  110245.jpg                 tungro   Zonal   55
# 10406  110381.jpg                 tungro   Zonal   55
#
# [10407 rows x 4 columns]

# %%
labels=list(np.unique(train_table['label']))
labels
# Out:
# ['bacterial_leaf_blight',
#  'bacterial_leaf_streak',
#  'bacterial_panicle_blight',
#  'blast',
#  'brown_spot',
#  'dead_heart',
#  'downy_mildew',
#  'hispa',
#  'normal',
#  'tungro']

# %%
train_dir= 'thesis/dataset/paddy_doctor/train/'
val_dir= 'thesis/dataset/paddy_doctor/val/'
img_size= 224

train_files= posixpath.join(code_runtime, train_dir)
test_files= posixpath.join(code_runtime, val_dir)

train_data= tf.keras.utils.image_dataset_from_directory(train_files,
                                                        labels='inferred',
                                                        label_mode='categorical',
                                                        validation_split=0.2,
                                                        subset="training",
                                                        class_names=labels,
                                                        color_mode='rgb',
                                                        image_size=(img_size, img_size),
                                                        shuffle=True,
                                                        seed= 42,
                                                        batch_size= 16)

val_data= tf.keras.utils.image_dataset_from_directory(train_files,
                                                        labels= 'inferred',
                                                        label_mode='categorical',
                                                        validation_split=0.2,
                                                        subset="validation",
                                                        class_names= labels,
                                                        color_mode='rgb',
                                                        image_size=(img_size, img_size),
                                                        shuffle=True,
                                                        seed= 42,
                                                        batch_size= 16)


test_datagen= ImageDataGenerator()
test_data= test_datagen.flow_from_directory(test_files,
                                            target_size= (img_size, img_size),
                                            batch_size= 16,
                                            shuffle = False, 
                                            class_mode='categorical')
# Out:
# Found 14302 files belonging to 10 classes.
# Using 11442 files for training.
# Found 14302 files belonging to 10 classes.
# Using 2860 files for validation.
# Found 1500 images belonging to 10 classes.

# %%
class_names = train_data.class_names
print(class_names)
# Out:
# ['bacterial_leaf_blight', 'bacterial_leaf_streak', 'bacterial_panicle_blight', 'blast', 'brown_spot', 'dead_heart', 'downy_mildew', 'hispa', 'normal', 'tungro']

# %%
test_data.class_indices
# Out:
# {'bacterial_leaf_blight': 0,
#  'bacterial_leaf_streak': 1,
#  'bacterial_panicle_blight': 2,
#  'blast': 3,
#  'brown_spot': 4,
#  'dead_heart': 5,
#  'downy_mildew': 6,
#  'hispa': 7,
#  'normal': 8,
#  'tungro': 9}

# %% [markdown]
# ## VGG16 (No Augmentation + Transfer Learning + Fine Tune)

# %%
base_model= tf.keras.applications.VGG16(
    include_top= False,
    weights= 'imagenet',
    input_shape=(img_size, img_size, 3),
    pooling= 'max'
)

# %%
tf.keras.utils.plot_model(
    base_model,
    show_shapes= True,
    show_dtype=False,
    show_layer_names=True,
    rankdir="TR",
    expand_nested=False,
    dpi=72,
    layer_range=None,
    show_layer_activations=True,
)

# %%
inputs= tf.keras.Input(shape= (img_size, img_size, 3))
preprocess_layer= tf.keras.applications.resnet50.preprocess_input(inputs)
normalization_layer= tf.keras.layers.Rescaling(scale= 1./127.5, offset= -1)(preprocess_layer)
x= base_model(normalization_layer)
x= tf.keras.layers.Dropout(0.3)(x)
x= tf.keras.layers.Dense(256, activation= 'relu')(x)
x= tf.keras.layers.Dropout(0.25)(x)
outputs= tf.keras.layers.Dense(10, activation= 'softmax')(x)

# %%
model= tf.keras.Model(inputs= inputs, outputs= outputs, name= "vgg16_TL_no_augmentation")

# %%
model.summary()
# Out:
# Model: "vgg16_TL_no_augmentation"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem (S  (None, 224, 224, 3)      0
#  licingOpLambda)
#
#  tf.nn.bias_add (TFOpLambda)  (None, 224, 224, 3)      0
#
#  rescaling (Rescaling)       (None, 224, 224, 3)       0
#
#  vgg16 (Functional)          (None, 512)               14714688
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense (Dense)               (None, 256)               131328
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 14,848,586
# Trainable params: 14,848,586
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(
    model,
    show_shapes= True,
    show_dtype=False,
    show_layer_names=True,
    rankdir="TR",
    expand_nested=False,
    dpi=72,
    layer_range=None,
    show_layer_activations=True,
)

# %%
# %%time
n_epochs= 100

filepath= "weights-improvement-{epoch:02d}-{val_accuracy:.4f}.hdf5"
checkpoint_callback= ModelCheckpoint(filepath, monitor= 'val_accuracy', verbose= 1, save_best_only= True, mode= 'max')
early_stop_callback= EarlyStopping(monitor='val_accuracy', patience= 5, verbose= False, mode='max')
callbacks_list=[checkpoint_callback, early_stop_callback]
# Out:
# CPU times: user 115 µs, sys: 0 ns, total: 115 µs
# Wall time: 119 µs

# %%
optimizer_adam_amsgrad= tf.keras.optimizers.Adam(learning_rate= 1e-4, amsgrad= True)
optimizer_adam= tf.keras.optimizers.Adam(learning_rate= 1e-4, amsgrad= False)
optimizer_sgd= tf.keras.optimizers.SGD(lr=1e-4, momentum= 0.9)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizers/optimizer_v2/gradient_descent.py:108: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)

# %%
model.compile(
        optimizer = optimizer_sgd,
        loss = 'categorical_crossentropy', 
        metrics = ['accuracy', tfa.metrics.F1Score(average='macro', num_classes= 10)]
        )

# %%
history= model.fit(train_data,
                  epochs= n_epochs,
                  validation_data= val_data,
                  callbacks= callbacks_list,
                  verbose= 1)
# Out:
# Epoch 1/100
# 716/716 [==============================] - ETA: 0s - loss: 2.2789 - accuracy: 0.1488 - f1_score: 0.1464
# Epoch 1: val_accuracy improved from -inf to 0.25594, saving model to weights-improvement-01-0.2559.hdf5
# 716/716 [==============================] - 228s 310ms/step - loss: 2.2789 - accuracy: 0.1488 - f1_score: 0.1464 - val_loss: 2.1071 - val_accuracy: 0.2559 - val_f1_score: 0.1947
# Epoch 2/100
# 715/716 [============================>.] - ETA: 0s - loss: 2.0673 - accuracy: 0.2393 - f1_score: 0.2299
# Epoch 2: val_accuracy improved from 0.25594 to 0.34301, saving model to weights-improvement-02-0.3430.hdf5
# 716/716 [==============================] - 30s 42ms/step - loss: 2.0674 - accuracy: 0.2393 - f1_score: 0.2298 - val_loss: 1.9361 - val_accuracy: 0.3430 - val_f1_score: 0.3041
# Epoch 3/100
# 714/716 [============================>.] - ETA: 0s - loss: 1.9021 - accuracy: 0.3154 - f1_score: 0.3078
# Epoch 3: val_accuracy improved from 0.34301 to 0.42203, saving model to weights-improvement-03-0.4220.hdf5
# 716/716 [==============================] - 30s 42ms/step - loss: 1.9023 - accuracy: 0.3155 - f1_score: 0.3080 - val_loss: 1.6951 - val_accuracy: 0.4220 - val_f1_score: 0.3891
# Epoch 4/100
# 715/716 [============================>.] - ETA: 0s - loss: 1.6968 - accuracy: 0.3983 - f1_score: 0.3932
# Epoch 4: val_accuracy improved from 0.42203 to 0.51923, saving model to weights-improvement-04-0.5192.hdf5
# 716/716 [==============================] - 30s 42ms/step - loss: 1.6968 - accuracy: 0.3984 - f1_score: 0.3932 - val_loss: 1.4607 - val_accuracy: 0.5192 - val_f1_score: 0.5102
# Epoch 5/100
# 715/716 [============================>.] - ETA: 0s - loss: 1.4431 - accuracy: 0.4923 - f1_score: 0.4876
# Epoch 5: val_accuracy improved from 0.51923 to 0.58951, saving model to weights-improvement-05-0.5895.hdf5
# 716/716 [==============================] - 30s 42ms/step - loss: 1.4431 - accuracy: 0.4923 - f1_score: 0.4876 - val_loss: 1.2190 - val_accuracy: 0.5895 - val_f1_score: 0.5625
# Epoch 6/100
# 715/716 [============================>.] - ETA: 0s - loss: 1.1940 - accuracy: 0.5879 - f1_score: 0.5839
# Epoch 6: val_accuracy improved from 0.58951 to 0.68741, saving model to weights-improvement-06-0.6874.hdf5
# 716/716 [==============================] - 30s 42ms/step - loss: 1.1939 - accuracy: 0.5879 - f1_score: 0.5839 - val_loss: 0.9519 - val_accuracy: 0.6874 - val_f1_score: 0.6803
# Epoch 7/100
# 714/716 [============================>.] - ETA: 0s - loss: 1.0071 - accuracy: 0.6532 - f1_score: 0.6494
# Epoch 7: val_accuracy improved from 0.68741 to 0.75350, saving model to weights-improvement-07-0.7535.hdf5
# 716/716 [==============================] - 30s 42ms/step - loss: 1.0075 - accuracy: 0.6529 - f1_score: 0.6492 - val_loss: 0.7567 - val_accuracy: 0.7535 - val_f1_score: 0.7458
# Epoch 8/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.8534 - accuracy: 0.7115 - f1_score: 0.7084
# Epoch 8: val_accuracy improved from 0.75350 to 0.77273, saving model to weights-improvement-08-0.7727.hdf5
# 716/716 [==============================] - 30s 42ms/step - loss: 0.8533 - accuracy: 0.7115 - f1_score: 0.7084 - val_loss: 0.7150 - val_accuracy: 0.7727 - val_f1_score: 0.7686
# Epoch 9/100
# 714/716 [============================>.] - ETA: 0s - loss: 0.7320 - accuracy: 0.7505 - f1_score: 0.7478
# Epoch 9: val_accuracy improved from 0.77273 to 0.81294, saving model to weights-improvement-09-0.8129.hdf5
# 716/716 [==============================] - 30s 42ms/step - loss: 0.7315 - accuracy: 0.7508 - f1_score: 0.7481 - val_loss: 0.6052 - val_accuracy: 0.8129 - val_f1_score: 0.8100
# Epoch 10/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.6110 - accuracy: 0.7948 - f1_score: 0.7925
# Epoch 10: val_accuracy improved from 0.81294 to 0.82832, saving model to weights-improvement-10-0.8283.hdf5
# 716/716 [==============================] - 30s 42ms/step - loss: 0.6109 - accuracy: 0.7948 - f1_score: 0.7925 - val_loss: 0.5458 - val_accuracy: 0.8283 - val_f1_score: 0.8287
# Epoch 11/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.5492 - accuracy: 0.8148 - f1_score: 0.8132
# Epoch 11: val_accuracy improved from 0.82832 to 0.86189, saving model to weights-improvement-11-0.8619.hdf5
# 716/716 [==============================] - 30s 41ms/step - loss: 0.5494 - accuracy: 0.8147 - f1_score: 0.8132 - val_loss: 0.4460 - val_accuracy: 0.8619 - val_f1_score: 0.8607
# Epoch 12/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.4610 - accuracy: 0.8476 - f1_score: 0.8463
# Epoch 12: val_accuracy did not improve from 0.86189
# 716/716 [==============================] - 30s 41ms/step - loss: 0.4611 - accuracy: 0.8475 - f1_score: 0.8462 - val_loss: 0.4223 - val_accuracy: 0.8584 - val_f1_score: 0.8558
# Epoch 13/100
# 714/716 [============================>.] - ETA: 0s - loss: 0.4186 - accuracy: 0.8648 - f1_score: 0.8637
# Epoch 13: val_accuracy improved from 0.86189 to 0.87937, saving model to weights-improvement-13-0.8794.hdf5
# 716/716 [==============================] - 30s 41ms/step - loss: 0.4193 - accuracy: 0.8646 - f1_score: 0.8635 - val_loss: 0.3930 - val_accuracy: 0.8794 - val_f1_score: 0.8782
# Epoch 14/100
# 714/716 [============================>.] - ETA: 0s - loss: 0.3643 - accuracy: 0.8799 - f1_score: 0.8790
# Epoch 14: val_accuracy improved from 0.87937 to 0.88042, saving model to weights-improvement-14-0.8804.hdf5
# 716/716 [==============================] - 30s 42ms/step - loss: 0.3641 - accuracy: 0.8798 - f1_score: 0.8789 - val_loss: 0.3891 - val_accuracy: 0.8804 - val_f1_score: 0.8814
# Epoch 15/100
# 714/716 [============================>.] - ETA: 0s - loss: 0.2928 - accuracy: 0.9035 - f1_score: 0.9028
# Epoch 15: val_accuracy improved from 0.88042 to 0.88636, saving model to weights-improvement-15-0.8864.hdf5
# 716/716 [==============================] - 30s 41ms/step - loss: 0.2931 - accuracy: 0.9033 - f1_score: 0.9027 - val_loss: 0.3707 - val_accuracy: 0.8864 - val_f1_score: 0.8855
# Epoch 16/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.2710 - accuracy: 0.9111 - f1_score: 0.9105
# Epoch 16: val_accuracy improved from 0.88636 to 0.90035, saving model to weights-improvement-16-0.9003.hdf5
# 716/716 [==============================] - 30s 42ms/step - loss: 0.2709 - accuracy: 0.9111 - f1_score: 0.9105 - val_loss: 0.3443 - val_accuracy: 0.9003 - val_f1_score: 0.9000
# Epoch 17/100
# 714/716 [============================>.] - ETA: 0s - loss: 0.2343 - accuracy: 0.9230 - f1_score: 0.9224
# Epoch 17: val_accuracy did not improve from 0.90035
# 716/716 [==============================] - 30s 41ms/step - loss: 0.2344 - accuracy: 0.9230 - f1_score: 0.9224 - val_loss: 0.3818 - val_accuracy: 0.8811 - val_f1_score: 0.8800
# Epoch 18/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.2055 - accuracy: 0.9302 - f1_score: 0.9297
# Epoch 18: val_accuracy improved from 0.90035 to 0.91014, saving model to weights-improvement-18-0.9101.hdf5
# 716/716 [==============================] - 30s 42ms/step - loss: 0.2055 - accuracy: 0.9303 - f1_score: 0.9297 - val_loss: 0.3121 - val_accuracy: 0.9101 - val_f1_score: 0.9094
# Epoch 19/100
# 714/716 [============================>.] - ETA: 0s - loss: 0.1833 - accuracy: 0.9413 - f1_score: 0.9409
# Epoch 19: val_accuracy did not improve from 0.91014
# 716/716 [==============================] - 30s 41ms/step - loss: 0.1836 - accuracy: 0.9413 - f1_score: 0.9410 - val_loss: 0.3055 - val_accuracy: 0.9091 - val_f1_score: 0.9088
# Epoch 20/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.1496 - accuracy: 0.9493 - f1_score: 0.9491
# Epoch 20: val_accuracy did not improve from 0.91014
# 716/716 [==============================] - 30s 41ms/step - loss: 0.1496 - accuracy: 0.9493 - f1_score: 0.9491 - val_loss: 0.3250 - val_accuracy: 0.9024 - val_f1_score: 0.9016
# Epoch 21/100
# 714/716 [============================>.] - ETA: 0s - loss: 0.1470 - accuracy: 0.9524 - f1_score: 0.9523
# Epoch 21: val_accuracy improved from 0.91014 to 0.92133, saving model to weights-improvement-21-0.9213.hdf5
# 716/716 [==============================] - 30s 42ms/step - loss: 0.1469 - accuracy: 0.9525 - f1_score: 0.9524 - val_loss: 0.2690 - val_accuracy: 0.9213 - val_f1_score: 0.9211
# Epoch 22/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.1262 - accuracy: 0.9594 - f1_score: 0.9593
# Epoch 22: val_accuracy did not improve from 0.92133
# 716/716 [==============================] - 30s 41ms/step - loss: 0.1262 - accuracy: 0.9594 - f1_score: 0.9593 - val_loss: 0.2735 - val_accuracy: 0.9178 - val_f1_score: 0.9185
# Epoch 23/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.1216 - accuracy: 0.9600 - f1_score: 0.9598
# Epoch 23: val_accuracy did not improve from 0.92133
# 716/716 [==============================] - 30s 41ms/step - loss: 0.1215 - accuracy: 0.9600 - f1_score: 0.9598 - val_loss: 0.2954 - val_accuracy: 0.9147 - val_f1_score: 0.9144
# Epoch 24/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.1046 - accuracy: 0.9665 - f1_score: 0.9664
# Epoch 24: val_accuracy did not improve from 0.92133
# 716/716 [==============================] - 30s 41ms/step - loss: 0.1046 - accuracy: 0.9665 - f1_score: 0.9665 - val_loss: 0.2945 - val_accuracy: 0.9182 - val_f1_score: 0.9176
# Epoch 25/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.1001 - accuracy: 0.9666 - f1_score: 0.9665
# Epoch 25: val_accuracy improved from 0.92133 to 0.92762, saving model to weights-improvement-25-0.9276.hdf5
# 716/716 [==============================] - 30s 41ms/step - loss: 0.1000 - accuracy: 0.9666 - f1_score: 0.9666 - val_loss: 0.2572 - val_accuracy: 0.9276 - val_f1_score: 0.9273
# Epoch 26/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.0908 - accuracy: 0.9719 - f1_score: 0.9717
# Epoch 26: val_accuracy did not improve from 0.92762
# 716/716 [==============================] - 30s 42ms/step - loss: 0.0908 - accuracy: 0.9719 - f1_score: 0.9718 - val_loss: 0.3019 - val_accuracy: 0.9199 - val_f1_score: 0.9193
# Epoch 27/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.0805 - accuracy: 0.9744 - f1_score: 0.9743
# Epoch 27: val_accuracy did not improve from 0.92762
# 716/716 [==============================] - 30s 41ms/step - loss: 0.0804 - accuracy: 0.9744 - f1_score: 0.9743 - val_loss: 0.2810 - val_accuracy: 0.9266 - val_f1_score: 0.9264
# Epoch 28/100
# 714/716 [============================>.] - ETA: 0s - loss: 0.0779 - accuracy: 0.9747 - f1_score: 0.9747
# Epoch 28: val_accuracy improved from 0.92762 to 0.93217, saving model to weights-improvement-28-0.9322.hdf5
# 716/716 [==============================] - 30s 42ms/step - loss: 0.0779 - accuracy: 0.9747 - f1_score: 0.9747 - val_loss: 0.2819 - val_accuracy: 0.9322 - val_f1_score: 0.9315
# Epoch 29/100
# 714/716 [============================>.] - ETA: 0s - loss: 0.0633 - accuracy: 0.9804 - f1_score: 0.9803
# Epoch 29: val_accuracy did not improve from 0.93217
# 716/716 [==============================] - 30s 41ms/step - loss: 0.0632 - accuracy: 0.9804 - f1_score: 0.9804 - val_loss: 0.3036 - val_accuracy: 0.9231 - val_f1_score: 0.9228
# Epoch 30/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.0699 - accuracy: 0.9778 - f1_score: 0.9778
# Epoch 30: val_accuracy did not improve from 0.93217
# 716/716 [==============================] - 30s 41ms/step - loss: 0.0699 - accuracy: 0.9778 - f1_score: 0.9778 - val_loss: 0.3260 - val_accuracy: 0.9147 - val_f1_score: 0.9152
# Epoch 31/100
# 714/716 [============================>.] - ETA: 0s - loss: 0.0572 - accuracy: 0.9821 - f1_score: 0.9821
# Epoch 31: val_accuracy did not improve from 0.93217
# 716/716 [==============================] - 30s 41ms/step - loss: 0.0572 - accuracy: 0.9822 - f1_score: 0.9821 - val_loss: 0.2886 - val_accuracy: 0.9238 - val_f1_score: 0.9237
# Epoch 32/100
# 714/716 [============================>.] - ETA: 0s - loss: 0.0563 - accuracy: 0.9842 - f1_score: 0.9841
# Epoch 32: val_accuracy did not improve from 0.93217
# 716/716 [==============================] - 30s 41ms/step - loss: 0.0563 - accuracy: 0.9842 - f1_score: 0.9841 - val_loss: 0.3057 - val_accuracy: 0.9241 - val_f1_score: 0.9227
# Epoch 33/100
# 714/716 [============================>.] - ETA: 0s - loss: 0.0640 - accuracy: 0.9797 - f1_score: 0.9796
# Epoch 33: val_accuracy improved from 0.93217 to 0.93846, saving model to weights-improvement-33-0.9385.hdf5
# 716/716 [==============================] - 30s 42ms/step - loss: 0.0639 - accuracy: 0.9797 - f1_score: 0.9797 - val_loss: 0.2472 - val_accuracy: 0.9385 - val_f1_score: 0.9378
# Epoch 34/100
# 714/716 [============================>.] - ETA: 0s - loss: 0.0485 - accuracy: 0.9854 - f1_score: 0.9854
# Epoch 34: val_accuracy did not improve from 0.93846
# 716/716 [==============================] - 30s 41ms/step - loss: 0.0485 - accuracy: 0.9854 - f1_score: 0.9854 - val_loss: 0.2852 - val_accuracy: 0.9329 - val_f1_score: 0.9326
# Epoch 35/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.0432 - accuracy: 0.9865 - f1_score: 0.9864
# Epoch 35: val_accuracy did not improve from 0.93846
# 716/716 [==============================] - 30s 41ms/step - loss: 0.0432 - accuracy: 0.9865 - f1_score: 0.9864 - val_loss: 0.2834 - val_accuracy: 0.9322 - val_f1_score: 0.9316
# Epoch 36/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.0459 - accuracy: 0.9865 - f1_score: 0.9864
# Epoch 36: val_accuracy did not improve from 0.93846
# 716/716 [==============================] - 30s 41ms/step - loss: 0.0459 - accuracy: 0.9865 - f1_score: 0.9864 - val_loss: 0.3325 - val_accuracy: 0.9283 - val_f1_score: 0.9272
# Epoch 37/100
# 714/716 [============================>.] - ETA: 0s - loss: 0.0319 - accuracy: 0.9909 - f1_score: 0.9909
# Epoch 37: val_accuracy did not improve from 0.93846
# 716/716 [==============================] - 30s 41ms/step - loss: 0.0319 - accuracy: 0.9909 - f1_score: 0.9909 - val_loss: 0.2975 - val_accuracy: 0.9346 - val_f1_score: 0.9344
# Epoch 38/100
# 714/716 [============================>.] - ETA: 0s - loss: 0.0299 - accuracy: 0.9900 - f1_score: 0.9900
# Epoch 38: val_accuracy did not improve from 0.93846
# 716/716 [==============================] - 30s 41ms/step - loss: 0.0300 - accuracy: 0.9900 - f1_score: 0.9900 - val_loss: 0.3386 - val_accuracy: 0.9241 - val_f1_score: 0.9239

# %%
model.evaluate(test_data, batch_size= 16, return_dict= True)
# Out:
# 94/94 [==============================] - 354s 4s/step - loss: 0.3112 - accuracy: 0.9347 - f1_score: 0.9347
# {'loss': 0.31118521094322205,
#  'accuracy': 0.9346666932106018,
#  'f1_score': 0.9346647262573242}

# %%
# Generating Confusion Matrix and Classification Report
Y_pred= model.predict_generator(test_data, 1500// 16 + 1)
y_pred= np.argmax(Y_pred, axis= 1)
print('Confusion Matrix')
conf_matrix= confusion_matrix(test_data.classes, y_pred)
conf_mat = np.array2string(conf_matrix)
#print(conf_matrix)
#print("=============================================================================================")
print('Classification Report')
target_names= test_data.class_indices
class_rep_vgg = classification_report(test_data.classes, y_pred, target_names=target_names)
print(class_rep_vgg)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
# Confusion Matrix
# Classification Report
#                           precision    recall  f1-score   support
#
#    bacterial_leaf_blight       0.97      0.86      0.91       150
#    bacterial_leaf_streak       0.95      0.95      0.95       150
# bacterial_panicle_blight       0.97      0.97      0.97       150
#                    blast       0.87      0.97      0.91       150
#               brown_spot       0.96      0.89      0.92       150
#               dead_heart       0.97      0.99      0.98       150
#             downy_mildew       0.85      0.93      0.89       150
#                    hispa       0.94      0.89      0.91       150
#                   normal       0.95      0.93      0.94       150
#                   tungro       0.93      0.97      0.95       150
#
#                 accuracy                           0.93      1500
#                macro avg       0.94      0.93      0.93      1500
#             weighted avg       0.94      0.93      0.93      1500

# %%
ConfusionMatrixDisplay.from_predictions(test_data.classes, y_pred, display_labels= target_names, xticks_rotation= 'vertical')
