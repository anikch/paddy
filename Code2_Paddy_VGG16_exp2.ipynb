# %% [markdown]
# <a href="https://colab.research.google.com/github/anikch/paddy/blob/main/Code2_Paddy_VGG16_exp2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow_addons
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow_addons
#   Downloading tensorflow_addons-0.18.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 4.7 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tensorflow_addons) (21.3)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow_addons) (2.7.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tensorflow_addons) (3.0.9)
# Installing collected packages: tensorflow-addons
# Successfully installed tensorflow-addons-0.18.0

# %%
# !pip install keras_cv
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting keras_cv
#   Downloading keras_cv-0.3.4-py3-none-any.whl (394 kB)
#      |████████████████████████████████| 394 kB 4.5 MB/s
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from keras_cv) (2022.6.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from keras_cv) (21.3)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.7/dist-packages (from keras_cv) (1.3.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->keras_cv) (3.0.9)
# Installing collected packages: keras-cv
# Successfully installed keras-cv-0.3.4

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import tensorflow_addons as tfa
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import seaborn as sns
from typing import List
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from functools import partial
import posixpath
from keras import models, regularizers, layers, optimizers, losses, metrics
import keras_cv
from keras.models import Sequential
from keras.layers import Dense
from tensorflow.keras.utils import plot_model

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !nvidia-smi
# Out:
# Mon Oct 24 21:52:12 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  A100-SXM4-40GB      Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   29C    P0    44W / 400W |      0MiB / 40536MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
colab= '/content/drive/MyDrive'
local= r'G:\My Drive'

code_runtime= colab

# %%
tf.__version__
# Out:
# '2.9.2'

# %%
file1= 'thesis/dataset/paddy_doctor/train.csv'
inp_file = posixpath.join(code_runtime, file1)

train_table=pd.read_csv(inp_file)
train_table
# Out:
#          image_id                  label variety  age
# 0      100330.jpg  bacterial_leaf_blight   ADT45   45
# 1      100365.jpg  bacterial_leaf_blight   ADT45   45
# 2      100382.jpg  bacterial_leaf_blight   ADT45   45
# 3      100632.jpg  bacterial_leaf_blight   ADT45   45
# 4      101918.jpg  bacterial_leaf_blight   ADT45   45
# ...           ...                    ...     ...  ...
# 10402  107607.jpg                 tungro   Zonal   55
# 10403  107811.jpg                 tungro   Zonal   55
# 10404  108547.jpg                 tungro   Zonal   55
# 10405  110245.jpg                 tungro   Zonal   55
# 10406  110381.jpg                 tungro   Zonal   55
#
# [10407 rows x 4 columns]

# %%
labels=list(np.unique(train_table['label']))
labels
# Out:
# ['bacterial_leaf_blight',
#  'bacterial_leaf_streak',
#  'bacterial_panicle_blight',
#  'blast',
#  'brown_spot',
#  'dead_heart',
#  'downy_mildew',
#  'hispa',
#  'normal',
#  'tungro']

# %%
train_dir= 'thesis/dataset/paddy_doctor/train/'
val_dir= 'thesis/dataset/paddy_doctor/val/'
img_size= 224

train_files= posixpath.join(code_runtime, train_dir)
test_files= posixpath.join(code_runtime, val_dir)

train_data= tf.keras.utils.image_dataset_from_directory(train_files,
                                                        labels='inferred',
                                                        label_mode='categorical',
                                                        validation_split=0.2,
                                                        subset="training",
                                                        class_names=labels,
                                                        color_mode='rgb',
                                                        image_size=(img_size, img_size),
                                                        shuffle=True,
                                                        seed= 42,
                                                        batch_size= 16)

val_data= tf.keras.utils.image_dataset_from_directory(train_files,
                                                        labels= 'inferred',
                                                        label_mode='categorical',
                                                        validation_split=0.2,
                                                        subset="validation",
                                                        class_names= labels,
                                                        color_mode='rgb',
                                                        image_size=(img_size, img_size),
                                                        shuffle=True,
                                                        seed= 42,
                                                        batch_size= 16)


test_datagen= ImageDataGenerator()
test_data= test_datagen.flow_from_directory(test_files,
                                            target_size= (img_size, img_size),
                                            batch_size= 16,
                                            shuffle = False, 
                                            class_mode='categorical')
# Out:
# Found 14302 files belonging to 10 classes.
# Using 11442 files for training.
# Found 14302 files belonging to 10 classes.
# Using 2860 files for validation.
# Found 1500 images belonging to 10 classes.

# %%
class_names = train_data.class_names
print(class_names)
# Out:
# ['bacterial_leaf_blight', 'bacterial_leaf_streak', 'bacterial_panicle_blight', 'blast', 'brown_spot', 'dead_heart', 'downy_mildew', 'hispa', 'normal', 'tungro']

# %%
test_data.class_indices
# Out:
# {'bacterial_leaf_blight': 0,
#  'bacterial_leaf_streak': 1,
#  'bacterial_panicle_blight': 2,
#  'blast': 3,
#  'brown_spot': 4,
#  'dead_heart': 5,
#  'downy_mildew': 6,
#  'hispa': 7,
#  'normal': 8,
#  'tungro': 9}

# %% [markdown]
# ## VGG16 (No Augmentation + Transfer Learning + Fine Tune)

# %%
base_model= tf.keras.applications.VGG16(
    include_top= False,
    weights= 'imagenet',
    input_shape=(img_size, img_size, 3),
    pooling= 'max'
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step

# %%
tf.keras.utils.plot_model(
    base_model,
    show_shapes= True,
    show_dtype=False,
    show_layer_names=True,
    rankdir="TR",
    expand_nested=False,
    dpi=72,
    layer_range=None,
    show_layer_activations=True,
)

# %%
inputs= tf.keras.Input(shape= (img_size, img_size, 3))
preprocess_layer= tf.keras.applications.vgg16.preprocess_input(inputs)
normalization_layer= tf.keras.layers.Rescaling(scale= 1./127.5, offset= -1)(preprocess_layer)
x= base_model(normalization_layer)
x= tf.keras.layers.Dropout(0.25)(x)
outputs= tf.keras.layers.Dense(10, activation= 'softmax')(x)

# %%
model= tf.keras.Model(inputs= inputs, outputs= outputs, name= "vgg16_TL_no_augmentation")

# %%
model.summary()
# Out:
# Model: "vgg16_TL_no_augmentation"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem (S  (None, 224, 224, 3)      0
#  licingOpLambda)
#
#  tf.nn.bias_add (TFOpLambda)  (None, 224, 224, 3)      0
#
#  rescaling (Rescaling)       (None, 224, 224, 3)       0
#
#  vgg16 (Functional)          (None, 512)               14714688
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense (Dense)               (None, 10)                5130
#
# =================================================================
# Total params: 14,719,818
# Trainable params: 14,719,818
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(
    model,
    show_shapes= True,
    show_dtype=False,
    show_layer_names=True,
    rankdir="TR",
    expand_nested=False,
    dpi=72,
    layer_range=None,
    show_layer_activations=True,
)

# %%
# %%time
n_epochs= 100

filepath= "weights-improvement-{epoch:02d}-{val_accuracy:.4f}.hdf5"
checkpoint_callback= ModelCheckpoint(filepath, monitor= 'val_accuracy', verbose= 1, save_best_only= True, mode= 'max')
early_stop_callback= EarlyStopping(monitor='val_accuracy', patience= 5, verbose= False, mode='max', restore_best_weights= True)
callbacks_list=[checkpoint_callback, early_stop_callback]
# Out:
# CPU times: user 64 µs, sys: 0 ns, total: 64 µs
# Wall time: 69.4 µs

# %%
optimizer_adam_amsgrad= tf.keras.optimizers.Adam(learning_rate= 1e-4, amsgrad= True)
optimizer_adam= tf.keras.optimizers.Adam(learning_rate= 1e-4, amsgrad= False)
optimizer_sgd= tf.keras.optimizers.SGD(learning_rate= 1e-4, momentum= 0.9)

# %%
model.compile(
        optimizer = optimizer_sgd,
        loss = 'categorical_crossentropy', 
        metrics = ['accuracy', tfa.metrics.F1Score(average='macro', num_classes= 10)]
        )

# %%
history= model.fit(train_data,
                  epochs= n_epochs,
                  validation_data= val_data,
                  callbacks= callbacks_list,
                  verbose= 1)
# Out:
# Epoch 1/100
# 716/716 [==============================] - ETA: 0s - loss: 1.7359 - accuracy: 0.3793 - f1_score: 0.3738
# Epoch 1: val_accuracy improved from -inf to 0.51084, saving model to weights-improvement-01-0.5108.hdf5
# 716/716 [==============================] - 385s 518ms/step - loss: 1.7359 - accuracy: 0.3793 - f1_score: 0.3738 - val_loss: 1.4207 - val_accuracy: 0.5108 - val_f1_score: 0.4980
# Epoch 2/100
# 714/716 [============================>.] - ETA: 0s - loss: 1.0279 - accuracy: 0.6417 - f1_score: 0.6377
# Epoch 2: val_accuracy improved from 0.51084 to 0.72308, saving model to weights-improvement-02-0.7231.hdf5
# 716/716 [==============================] - 32s 44ms/step - loss: 1.0282 - accuracy: 0.6418 - f1_score: 0.6377 - val_loss: 0.8506 - val_accuracy: 0.7231 - val_f1_score: 0.7198
# Epoch 3/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.7194 - accuracy: 0.7570 - f1_score: 0.7550
# Epoch 3: val_accuracy improved from 0.72308 to 0.78811, saving model to weights-improvement-03-0.7881.hdf5
# 716/716 [==============================] - 32s 44ms/step - loss: 0.7194 - accuracy: 0.7569 - f1_score: 0.7550 - val_loss: 0.6289 - val_accuracy: 0.7881 - val_f1_score: 0.7849
# Epoch 4/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.5238 - accuracy: 0.8254 - f1_score: 0.8244
# Epoch 4: val_accuracy improved from 0.78811 to 0.83077, saving model to weights-improvement-04-0.8308.hdf5
# 716/716 [==============================] - 32s 45ms/step - loss: 0.5239 - accuracy: 0.8253 - f1_score: 0.8243 - val_loss: 0.5272 - val_accuracy: 0.8308 - val_f1_score: 0.8318
# Epoch 5/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.3919 - accuracy: 0.8688 - f1_score: 0.8682
# Epoch 5: val_accuracy improved from 0.83077 to 0.86888, saving model to weights-improvement-05-0.8689.hdf5
# 716/716 [==============================] - 32s 45ms/step - loss: 0.3922 - accuracy: 0.8687 - f1_score: 0.8682 - val_loss: 0.4118 - val_accuracy: 0.8689 - val_f1_score: 0.8691
# Epoch 6/100
# 716/716 [==============================] - ETA: 0s - loss: 0.3084 - accuracy: 0.8983 - f1_score: 0.8980
# Epoch 6: val_accuracy improved from 0.86888 to 0.87972, saving model to weights-improvement-06-0.8797.hdf5
# 716/716 [==============================] - 32s 44ms/step - loss: 0.3084 - accuracy: 0.8983 - f1_score: 0.8980 - val_loss: 0.3779 - val_accuracy: 0.8797 - val_f1_score: 0.8783
# Epoch 7/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.2342 - accuracy: 0.9201 - f1_score: 0.9196
# Epoch 7: val_accuracy improved from 0.87972 to 0.89755, saving model to weights-improvement-07-0.8976.hdf5
# 716/716 [==============================] - 32s 45ms/step - loss: 0.2342 - accuracy: 0.9201 - f1_score: 0.9197 - val_loss: 0.3547 - val_accuracy: 0.8976 - val_f1_score: 0.8968
# Epoch 8/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.1828 - accuracy: 0.9399 - f1_score: 0.9398
# Epoch 8: val_accuracy improved from 0.89755 to 0.90734, saving model to weights-improvement-08-0.9073.hdf5
# 716/716 [==============================] - 32s 45ms/step - loss: 0.1828 - accuracy: 0.9399 - f1_score: 0.9398 - val_loss: 0.3110 - val_accuracy: 0.9073 - val_f1_score: 0.9071
# Epoch 9/100
# 716/716 [==============================] - ETA: 0s - loss: 0.1473 - accuracy: 0.9528 - f1_score: 0.9527
# Epoch 9: val_accuracy did not improve from 0.90734
# 716/716 [==============================] - 32s 44ms/step - loss: 0.1473 - accuracy: 0.9528 - f1_score: 0.9527 - val_loss: 0.3401 - val_accuracy: 0.9042 - val_f1_score: 0.9034
# Epoch 10/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.1109 - accuracy: 0.9655 - f1_score: 0.9654
# Epoch 10: val_accuracy improved from 0.90734 to 0.90839, saving model to weights-improvement-10-0.9084.hdf5
# 716/716 [==============================] - 32s 45ms/step - loss: 0.1108 - accuracy: 0.9655 - f1_score: 0.9654 - val_loss: 0.3391 - val_accuracy: 0.9084 - val_f1_score: 0.9073
# Epoch 11/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.1010 - accuracy: 0.9668 - f1_score: 0.9666
# Epoch 11: val_accuracy did not improve from 0.90839
# 716/716 [==============================] - 32s 45ms/step - loss: 0.1010 - accuracy: 0.9668 - f1_score: 0.9667 - val_loss: 0.3449 - val_accuracy: 0.9073 - val_f1_score: 0.9067
# Epoch 12/100
# 716/716 [==============================] - ETA: 0s - loss: 0.0829 - accuracy: 0.9733 - f1_score: 0.9732
# Epoch 12: val_accuracy improved from 0.90839 to 0.92063, saving model to weights-improvement-12-0.9206.hdf5
# 716/716 [==============================] - 32s 45ms/step - loss: 0.0829 - accuracy: 0.9733 - f1_score: 0.9732 - val_loss: 0.2844 - val_accuracy: 0.9206 - val_f1_score: 0.9204
# Epoch 13/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.0781 - accuracy: 0.9754 - f1_score: 0.9753
# Epoch 13: val_accuracy did not improve from 0.92063
# 716/716 [==============================] - 32s 44ms/step - loss: 0.0781 - accuracy: 0.9754 - f1_score: 0.9753 - val_loss: 0.3067 - val_accuracy: 0.9199 - val_f1_score: 0.9198
# Epoch 14/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.0651 - accuracy: 0.9796 - f1_score: 0.9796
# Epoch 14: val_accuracy improved from 0.92063 to 0.92413, saving model to weights-improvement-14-0.9241.hdf5
# 716/716 [==============================] - 32s 45ms/step - loss: 0.0651 - accuracy: 0.9796 - f1_score: 0.9796 - val_loss: 0.3075 - val_accuracy: 0.9241 - val_f1_score: 0.9237
# Epoch 15/100
# 716/716 [==============================] - ETA: 0s - loss: 0.0498 - accuracy: 0.9846 - f1_score: 0.9846
# Epoch 15: val_accuracy did not improve from 0.92413
# 716/716 [==============================] - 32s 45ms/step - loss: 0.0498 - accuracy: 0.9846 - f1_score: 0.9846 - val_loss: 0.3831 - val_accuracy: 0.9021 - val_f1_score: 0.9003
# Epoch 16/100
# 714/716 [============================>.] - ETA: 0s - loss: 0.0534 - accuracy: 0.9845 - f1_score: 0.9844
# Epoch 16: val_accuracy did not improve from 0.92413
# 716/716 [==============================] - 32s 44ms/step - loss: 0.0534 - accuracy: 0.9845 - f1_score: 0.9845 - val_loss: 0.3019 - val_accuracy: 0.9238 - val_f1_score: 0.9230
# Epoch 17/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.0410 - accuracy: 0.9882 - f1_score: 0.9882
# Epoch 17: val_accuracy did not improve from 0.92413
# 716/716 [==============================] - 33s 45ms/step - loss: 0.0410 - accuracy: 0.9882 - f1_score: 0.9882 - val_loss: 0.3413 - val_accuracy: 0.9213 - val_f1_score: 0.9200
# Epoch 18/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.0412 - accuracy: 0.9880 - f1_score: 0.9880
# Epoch 18: val_accuracy did not improve from 0.92413
# 716/716 [==============================] - 34s 47ms/step - loss: 0.0412 - accuracy: 0.9880 - f1_score: 0.9880 - val_loss: 0.2912 - val_accuracy: 0.9164 - val_f1_score: 0.9166
# Epoch 19/100
# 716/716 [==============================] - ETA: 0s - loss: 0.0381 - accuracy: 0.9879 - f1_score: 0.9877
# Epoch 19: val_accuracy improved from 0.92413 to 0.93636, saving model to weights-improvement-19-0.9364.hdf5
# 716/716 [==============================] - 34s 47ms/step - loss: 0.0381 - accuracy: 0.9879 - f1_score: 0.9877 - val_loss: 0.2824 - val_accuracy: 0.9364 - val_f1_score: 0.9361
# Epoch 20/100
# 716/716 [==============================] - ETA: 0s - loss: 0.0300 - accuracy: 0.9920 - f1_score: 0.9919
# Epoch 20: val_accuracy did not improve from 0.93636
# 716/716 [==============================] - 34s 47ms/step - loss: 0.0300 - accuracy: 0.9920 - f1_score: 0.9919 - val_loss: 0.2671 - val_accuracy: 0.9357 - val_f1_score: 0.9354
# Epoch 21/100
# 716/716 [==============================] - ETA: 0s - loss: 0.0238 - accuracy: 0.9927 - f1_score: 0.9928
# Epoch 21: val_accuracy improved from 0.93636 to 0.93706, saving model to weights-improvement-21-0.9371.hdf5
# 716/716 [==============================] - 34s 48ms/step - loss: 0.0238 - accuracy: 0.9927 - f1_score: 0.9928 - val_loss: 0.2652 - val_accuracy: 0.9371 - val_f1_score: 0.9368
# Epoch 22/100
# 716/716 [==============================] - ETA: 0s - loss: 0.0196 - accuracy: 0.9944 - f1_score: 0.9944
# Epoch 22: val_accuracy did not improve from 0.93706
# 716/716 [==============================] - 34s 47ms/step - loss: 0.0196 - accuracy: 0.9944 - f1_score: 0.9944 - val_loss: 0.3304 - val_accuracy: 0.9311 - val_f1_score: 0.9306
# Epoch 23/100
# 716/716 [==============================] - ETA: 0s - loss: 0.0185 - accuracy: 0.9945 - f1_score: 0.9945
# Epoch 23: val_accuracy improved from 0.93706 to 0.93741, saving model to weights-improvement-23-0.9374.hdf5
# 716/716 [==============================] - 34s 47ms/step - loss: 0.0185 - accuracy: 0.9945 - f1_score: 0.9945 - val_loss: 0.2970 - val_accuracy: 0.9374 - val_f1_score: 0.9368
# Epoch 24/100
# 716/716 [==============================] - ETA: 0s - loss: 0.0228 - accuracy: 0.9929 - f1_score: 0.9929
# Epoch 24: val_accuracy did not improve from 0.93741
# 716/716 [==============================] - 34s 47ms/step - loss: 0.0228 - accuracy: 0.9929 - f1_score: 0.9929 - val_loss: 0.2654 - val_accuracy: 0.9374 - val_f1_score: 0.9371
# Epoch 25/100
# 716/716 [==============================] - ETA: 0s - loss: 0.0274 - accuracy: 0.9925 - f1_score: 0.9924
# Epoch 25: val_accuracy did not improve from 0.93741
# 716/716 [==============================] - 33s 46ms/step - loss: 0.0274 - accuracy: 0.9925 - f1_score: 0.9924 - val_loss: 0.3450 - val_accuracy: 0.9210 - val_f1_score: 0.9205
# Epoch 26/100
# 715/716 [============================>.] - ETA: 0s - loss: 0.0216 - accuracy: 0.9935 - f1_score: 0.9935
# Epoch 26: val_accuracy did not improve from 0.93741
# 716/716 [==============================] - 32s 45ms/step - loss: 0.0216 - accuracy: 0.9935 - f1_score: 0.9935 - val_loss: 0.2782 - val_accuracy: 0.9332 - val_f1_score: 0.9331
# Epoch 27/100
# 716/716 [==============================] - ETA: 0s - loss: 0.0145 - accuracy: 0.9955 - f1_score: 0.9956
# Epoch 27: val_accuracy did not improve from 0.93741
# 716/716 [==============================] - 33s 45ms/step - loss: 0.0145 - accuracy: 0.9955 - f1_score: 0.9956 - val_loss: 0.3080 - val_accuracy: 0.9304 - val_f1_score: 0.9297
# Epoch 28/100
# 716/716 [==============================] - ETA: 0s - loss: 0.0172 - accuracy: 0.9951 - f1_score: 0.9951
# Epoch 28: val_accuracy did not improve from 0.93741
# 716/716 [==============================] - 33s 47ms/step - loss: 0.0172 - accuracy: 0.9951 - f1_score: 0.9951 - val_loss: 0.3025 - val_accuracy: 0.9346 - val_f1_score: 0.9338

# %%
model.evaluate(test_data, batch_size= 16, return_dict= True)
# Out:
# 94/94 [==============================] - 324s 3s/step - loss: 0.3334 - accuracy: 0.9407 - f1_score: 0.9404
# {'loss': 0.33337679505348206,
#  'accuracy': 0.940666675567627,
#  'f1_score': 0.9404028058052063}

# %%
model_load= tf.keras.models.load_model('/content/weights-improvement-23-0.9374.hdf5')
model_load.evaluate(test_data, batch_size= 16, return_dict= True)
# Out:
# 94/94 [==============================] - 12s 126ms/step - loss: 0.3334 - accuracy: 0.9407 - f1_score: 0.9404
# {'loss': 0.33337679505348206,
#  'accuracy': 0.940666675567627,
#  'f1_score': 0.9404028058052063}

# %%
# Generating Confusion Matrix and Classification Report
Y_pred= model.predict_generator(test_data, 1500// 16 + 1)
y_pred= np.argmax(Y_pred, axis= 1)
print('Confusion Matrix')
conf_matrix= confusion_matrix(test_data.classes, y_pred)
conf_mat = np.array2string(conf_matrix)
#print(conf_matrix)
#print("=============================================================================================")
print('Classification Report')
target_names= test_data.class_indices
class_rep_vgg = classification_report(test_data.classes, y_pred, target_names=target_names)
print(class_rep_vgg)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
# Confusion Matrix
# Classification Report
#                           precision    recall  f1-score   support
#
#    bacterial_leaf_blight       0.95      0.87      0.91       150
#    bacterial_leaf_streak       0.93      0.97      0.95       150
# bacterial_panicle_blight       0.97      0.97      0.97       150
#                    blast       0.90      0.97      0.93       150
#               brown_spot       0.91      0.91      0.91       150
#               dead_heart       0.96      0.99      0.98       150
#             downy_mildew       0.95      0.89      0.92       150
#                    hispa       0.94      0.93      0.93       150
#                   normal       0.97      0.97      0.97       150
#                   tungro       0.94      0.96      0.95       150
#
#                 accuracy                           0.94      1500
#                macro avg       0.94      0.94      0.94      1500
#             weighted avg       0.94      0.94      0.94      1500

# %%
ConfusionMatrixDisplay.from_predictions(test_data.classes, y_pred, display_labels= target_names, xticks_rotation= 'vertical')
