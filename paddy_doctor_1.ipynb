# %% [markdown]
# <a href="https://colab.research.google.com/github/anikch/paddy/blob/main/paddy_doctor_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow-addons
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.17.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 14.6 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tensorflow-addons) (21.3)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow-addons) (2.7.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tensorflow-addons) (3.0.9)
# Installing collected packages: tensorflow-addons
# Successfully installed tensorflow-addons-0.17.1

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import tensorflow_addons as tfa
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
import seaborn as sns
from typing import List
import tensorflow_hub as hub
from tensorflow import keras
from tensorflow.keras import layers

# %%
# !nvidia-smi
# Out:
# Wed Jul  6 19:17:23 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P0    25W / 300W |      0MiB / 16160MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
train_table=pd.read_csv("/content/drive/MyDrive/thesis/dataset/paddy_doctor/train.csv")
train_table
# Out:
#          image_id                  label variety  age
# 0      100330.jpg  bacterial_leaf_blight   ADT45   45
# 1      100365.jpg  bacterial_leaf_blight   ADT45   45
# 2      100382.jpg  bacterial_leaf_blight   ADT45   45
# 3      100632.jpg  bacterial_leaf_blight   ADT45   45
# 4      101918.jpg  bacterial_leaf_blight   ADT45   45
# ...           ...                    ...     ...  ...
# 10402  107607.jpg                 tungro   Zonal   55
# 10403  107811.jpg                 tungro   Zonal   55
# 10404  108547.jpg                 tungro   Zonal   55
# 10405  110245.jpg                 tungro   Zonal   55
# 10406  110381.jpg                 tungro   Zonal   55
#
# [10407 rows x 4 columns]

# %%
labels=list(np.unique(train_table['label']))
labels
# Out:
# ['bacterial_leaf_blight',
#  'bacterial_leaf_streak',
#  'bacterial_panicle_blight',
#  'blast',
#  'brown_spot',
#  'dead_heart',
#  'downy_mildew',
#  'hispa',
#  'normal',
#  'tungro']

# %%
train_data= tf.keras.utils.image_dataset_from_directory("/content/drive/MyDrive/thesis/dataset/paddy_doctor/train_images/",
                                                        labels='inferred',
                                                        label_mode='categorical',
                                                        class_names=labels,
                                                        color_mode='rgb',
                                                        image_size=(224,224),
                                                        shuffle=True,
                                                        validation_split=0.1,
                                                        subset='training',
                                                        batch_size= 128,
                                                        seed=42)

val_data= tf.keras.utils.image_dataset_from_directory("/content/drive/MyDrive/thesis/dataset/paddy_doctor/train_images/",
                                                        labels='inferred',
                                                        label_mode='categorical',
                                                        class_names=labels,
                                                        color_mode='rgb',
                                                        image_size=(224,224),
                                                        shuffle=True,
                                                        validation_split=0.1,
                                                        subset='validation',
                                                        batch_size=128,
                                                        seed=42)
# Out:
# Found 10407 files belonging to 10 classes.
# Using 9367 files for training.
# Found 10407 files belonging to 10 classes.
# Using 1040 files for validation.

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_data = train_data.cache().prefetch(buffer_size=AUTOTUNE)
val_data = val_data.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# # DeiT Model

# %%
# Model
MODEL_TYPE = "deit_distilled_tiny_patch16_224"
RESOLUTION = 224
PATCH_SIZE = 16
NUM_PATCHES = (RESOLUTION // PATCH_SIZE) ** 2
LAYER_NORM_EPS = 1e-6
PROJECTION_DIM = 192
NUM_HEADS = 3
NUM_LAYERS = 12
MLP_UNITS = [
    PROJECTION_DIM * 4,
    PROJECTION_DIM,
]
DROPOUT_RATE = 0.0
DROP_PATH_RATE = 0.1

# Training
NUM_EPOCHS = 20
BASE_LR = 0.0005
WEIGHT_DECAY = 0.0001

# Data
BATCH_SIZE = 128
AUTO = tf.data.AUTOTUNE
NUM_CLASSES = 10

# %%
class StochasticDepth(layers.Layer):
    def __init__(self, drop_prop, **kwargs):
        super().__init__(**kwargs)
        self.drop_prob = drop_prop

    def call(self, x, training=True):
        if training:
            keep_prob = 1 - self.drop_prob
            shape = (tf.shape(x)[0],) + (1,) * (len(tf.shape(x)) - 1)
            random_tensor = keep_prob + tf.random.uniform(shape, 0, 1)
            random_tensor = tf.floor(random_tensor)
            return (x / keep_prob) * random_tensor
        return x

# %%
def mlp(x, dropout_rate: float, hidden_units: List):
    """FFN for a Transformer block."""
    # Iterate over the hidden units and
    # add Dense => Dropout.
    for (idx, units) in enumerate(hidden_units):
        x = layers.Dense(
            units,
            activation=tf.nn.gelu if idx == 0 else None,
        )(x)
        x = layers.Dropout(dropout_rate)(x)
    return x


def transformer(drop_prob: float, name: str) -> keras.Model:
    """Transformer block with pre-norm."""
    num_patches = NUM_PATCHES + 2 if "distilled" in MODEL_TYPE else NUM_PATCHES + 1
    encoded_patches = layers.Input((num_patches, PROJECTION_DIM))

    # Layer normalization 1.
    x1 = layers.LayerNormalization(epsilon=LAYER_NORM_EPS)(encoded_patches)

    # Multi Head Self Attention layer 1.
    attention_output = layers.MultiHeadAttention(
        num_heads=NUM_HEADS,
        key_dim=PROJECTION_DIM,
        dropout=DROPOUT_RATE,
    )(x1, x1)
    attention_output = (
        StochasticDepth(drop_prob)(attention_output) if drop_prob else attention_output
    )

    # Skip connection 1.
    x2 = layers.Add()([attention_output, encoded_patches])

    # Layer normalization 2.
    x3 = layers.LayerNormalization(epsilon=LAYER_NORM_EPS)(x2)

    # MLP layer 1.
    x4 = mlp(x3, hidden_units=MLP_UNITS, dropout_rate=DROPOUT_RATE)
    x4 = StochasticDepth(drop_prob)(x4) if drop_prob else x4

    # Skip connection 2.
    outputs = layers.Add()([x2, x4])

    return keras.Model(encoded_patches, outputs, name=name)

# %%
class ViTClassifier(keras.Model):
    """Vision Transformer base class."""

    def __init__(self, **kwargs):
        super().__init__(**kwargs)

        # Patchify + linear projection + reshaping.
        self.projection = keras.Sequential(
            [
                layers.Conv2D(
                    filters=PROJECTION_DIM,
                    kernel_size=(PATCH_SIZE, PATCH_SIZE),
                    strides=(PATCH_SIZE, PATCH_SIZE),
                    padding="VALID",
                    name="conv_projection",
                ),
                layers.Reshape(
                    target_shape=(NUM_PATCHES, PROJECTION_DIM),
                    name="flatten_projection",
                ),
            ],
            name="projection",
        )

        # Positional embedding.
        init_shape = (
            1,
            NUM_PATCHES + 1,
            PROJECTION_DIM,
        )
        self.positional_embedding = tf.Variable(
            tf.zeros(init_shape), name="pos_embedding"
        )

        # Transformer blocks.
        dpr = [x for x in tf.linspace(0.0, DROP_PATH_RATE, NUM_LAYERS)]
        self.transformer_blocks = [
            transformer(drop_prob=dpr[i], name=f"transformer_block_{i}")
            for i in range(NUM_LAYERS)
        ]

        # CLS token.
        initial_value = tf.zeros((1, 1, PROJECTION_DIM))
        self.cls_token = tf.Variable(
            initial_value=initial_value, trainable=True, name="cls"
        )

        # Other layers.
        self.dropout = layers.Dropout(DROPOUT_RATE)
        self.layer_norm = layers.LayerNormalization(epsilon=LAYER_NORM_EPS)
        self.head = layers.Dense(
            NUM_CLASSES,
            name="classification_head",
        )

    def call(self, inputs, training=True):
        n = tf.shape(inputs)[0]

        # Create patches and project the patches.
        projected_patches = self.projection(inputs)

        # Append class token if needed.
        cls_token = tf.tile(self.cls_token, (n, 1, 1))
        cls_token = tf.cast(cls_token, projected_patches.dtype)
        projected_patches = tf.concat([cls_token, projected_patches], axis=1)

        # Add positional embeddings to the projected patches.
        encoded_patches = (
            self.positional_embedding + projected_patches
        )  # (B, number_patches, projection_dim)
        encoded_patches = self.dropout(encoded_patches)

        # Iterate over the number of layers and stack up blocks of
        # Transformer.
        for transformer_module in self.transformer_blocks:
            # Add a Transformer block.
            encoded_patches = transformer_module(encoded_patches)

        # Final layer normalization.
        representation = self.layer_norm(encoded_patches)

        # Pool representation.
        encoded_patches = representation[:, 0]

        # Classification head.
        output = self.head(encoded_patches)
        return output

# %%
class ViTDistilled(ViTClassifier):
    def __init__(self, regular_training=False, **kwargs):
        super().__init__(**kwargs)
        self.num_tokens = 2
        self.regular_training = regular_training

        # CLS and distillation tokens, positional embedding.
        init_value = tf.zeros((1, 1, PROJECTION_DIM))
        self.dist_token = tf.Variable(init_value, name="dist_token")
        self.positional_embedding = tf.Variable(
            tf.zeros(
                (
                    1,
                    NUM_PATCHES + self.num_tokens,
                    PROJECTION_DIM,
                )
            ),
            name="pos_embedding",
        )

        # Head layers.
        self.head = layers.Dense(
            NUM_CLASSES,
            name="classification_head",
        )
        self.head_dist = layers.Dense(
            NUM_CLASSES,
            name="distillation_head",
        )

    def call(self, inputs, training=True):
        n = tf.shape(inputs)[0]

        # Create patches and project the patches.
        projected_patches = self.projection(inputs)

        # Append the tokens.
        cls_token = tf.tile(self.cls_token, (n, 1, 1))
        dist_token = tf.tile(self.dist_token, (n, 1, 1))
        cls_token = tf.cast(cls_token, projected_patches.dtype)
        dist_token = tf.cast(dist_token, projected_patches.dtype)
        projected_patches = tf.concat(
            [cls_token, dist_token, projected_patches], axis=1
        )

        # Add positional embeddings to the projected patches.
        encoded_patches = (
            self.positional_embedding + projected_patches
        )  # (B, number_patches, projection_dim)
        encoded_patches = self.dropout(encoded_patches)

        # Iterate over the number of layers and stack up blocks of
        # Transformer.
        for transformer_module in self.transformer_blocks:
            # Add a Transformer block.
            encoded_patches = transformer_module(encoded_patches)

        # Final layer normalization.
        representation = self.layer_norm(encoded_patches)

        # Classification heads.
        x, x_dist = (
            self.head(representation[:, 0]),
            self.head_dist(representation[:, 1]),
        )

        if not training or self.regular_training:
            # During standard train / finetune, inference average the classifier
            # predictions.
            return (x + x_dist) / 2

        elif training:
            # Only return separate classification predictions when training in distilled
            # mode.
            return x, x_dist

# %%
deit_tiny_distilled = ViTDistilled()

dummy_inputs = tf.ones((2, 224, 224, 3))
outputs = deit_tiny_distilled(dummy_inputs, training=False)
print(outputs.shape)
# Out:
# (2, 10)

# %%
class DeiT(keras.Model):
    # Reference:
    # https://keras.io/examples/vision/knowledge_distillation/
    def __init__(self, student, teacher, **kwargs):
        super().__init__(**kwargs)
        self.student = student
        self.teacher = teacher

        self.student_loss_tracker = keras.metrics.Mean(name="student_loss")
        self.dist_loss_tracker = keras.metrics.Mean(name="distillation_loss")

    @property
    def metrics(self):
        metrics = super().metrics
        metrics.append(self.student_loss_tracker)
        metrics.append(self.dist_loss_tracker)
        return metrics

    def compile(
        self,
        optimizer,
        metrics,
        student_loss_fn,
        distillation_loss_fn,
    ):
        super().compile(optimizer=optimizer, metrics=metrics)
        self.student_loss_fn = student_loss_fn
        self.distillation_loss_fn = distillation_loss_fn

    def train_step(self, data):
        # Unpack data.
        x, y = data

        # Forward pass of teacher
        teacher_predictions = tf.nn.softmax(self.teacher(x, training=False), -1)
        teacher_predictions = tf.argmax(teacher_predictions, -1)

        with tf.GradientTape() as tape:
            # Forward pass of student.
            cls_predictions, dist_predictions = self.student(x / 255.0, training=True)

            # Compute losses.
            student_loss = self.student_loss_fn(y, cls_predictions)
            distillation_loss = self.distillation_loss_fn(
                teacher_predictions, dist_predictions
            )
            loss = (student_loss + distillation_loss) / 2

        # Compute gradients.
        trainable_vars = self.student.trainable_variables
        gradients = tape.gradient(loss, trainable_vars)

        # Update weights.
        self.optimizer.apply_gradients(zip(gradients, trainable_vars))

        # Update the metrics configured in `compile()`.
        student_predictions = (cls_predictions + dist_predictions) / 2
        self.compiled_metrics.update_state(y, student_predictions)
        self.dist_loss_tracker.update_state(distillation_loss)
        self.student_loss_tracker.update_state(student_loss)

        # Return a dict of performance.
        results = {m.name: m.result() for m in self.metrics}
        return results

    def test_step(self, data):
        # Unpack the data.
        x, y = data

        # Compute predictions.
        y_prediction = self.student(x / 255.0, training=False)

        # Calculate the loss.
        student_loss = self.student_loss_fn(y, y_prediction)

        # Update the metrics.
        self.compiled_metrics.update_state(y, y_prediction)
        self.student_loss_tracker.update_state(student_loss)

        # Return a dict of performance.
        results = {m.name: m.result() for m in self.metrics}
        return results

    def call(self, inputs):
        return self.student(inputs / 255.0, training=False)

# %%
bit_teacher_paddy_doc = keras.models.load_model("/content/drive/MyDrive/thesis/dataset/paddy_doctor/bit_teacher_paddy_doctor2")

# %%
NUM_EPOCHS= 100

# %%
deit_tiny = ViTDistilled()
deit_distiller = DeiT(student=deit_tiny, teacher= bit_teacher_paddy_doc)

lr_scaled = (BASE_LR / 512) * BATCH_SIZE
deit_distiller.compile(
    optimizer=tfa.optimizers.AdamW(weight_decay=WEIGHT_DECAY, learning_rate=lr_scaled),
    metrics=["accuracy"],
    student_loss_fn=keras.losses.CategoricalCrossentropy(
        from_logits=True, label_smoothing=0.1
    ),
    distillation_loss_fn=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
)
_ = deit_distiller.fit(train_data, validation_data=val_data, epochs=NUM_EPOCHS)
# Out:
# Epoch 1/100
# 74/74 [==============================] - 58s 580ms/step - accuracy: 0.1655 - student_loss: 2.2532 - distillation_loss: 2.2477 - val_accuracy: 0.1615 - val_student_loss: 2.2098 - val_distillation_loss: 0.0000e+00
# Epoch 2/100
# 74/74 [==============================] - 41s 559ms/step - accuracy: 0.1982 - student_loss: 2.1877 - distillation_loss: 2.1584 - val_accuracy: 0.1942 - val_student_loss: 2.1529 - val_distillation_loss: 0.0000e+00
# Epoch 3/100
# 74/74 [==============================] - 41s 560ms/step - accuracy: 0.2199 - student_loss: 2.1484 - distillation_loss: 2.0970 - val_accuracy: 0.2279 - val_student_loss: 2.1322 - val_distillation_loss: 0.0000e+00
# Epoch 4/100
# 74/74 [==============================] - 41s 559ms/step - accuracy: 0.2543 - student_loss: 2.1048 - distillation_loss: 2.0379 - val_accuracy: 0.2587 - val_student_loss: 2.1156 - val_distillation_loss: 0.0000e+00
# Epoch 5/100
# 74/74 [==============================] - 41s 559ms/step - accuracy: 0.2785 - student_loss: 2.0656 - distillation_loss: 1.9832 - val_accuracy: 0.2750 - val_student_loss: 2.0612 - val_distillation_loss: 0.0000e+00
# Epoch 6/100
# 74/74 [==============================] - 41s 560ms/step - accuracy: 0.3165 - student_loss: 1.9911 - distillation_loss: 1.8962 - val_accuracy: 0.2798 - val_student_loss: 2.0265 - val_distillation_loss: 0.0000e+00
# Epoch 7/100
# 74/74 [==============================] - 41s 560ms/step - accuracy: 0.3438 - student_loss: 1.9391 - distillation_loss: 1.8375 - val_accuracy: 0.3365 - val_student_loss: 1.9330 - val_distillation_loss: 0.0000e+00
# Epoch 8/100
# 74/74 [==============================] - 41s 560ms/step - accuracy: 0.3824 - student_loss: 1.8561 - distillation_loss: 1.7401 - val_accuracy: 0.3529 - val_student_loss: 1.9159 - val_distillation_loss: 0.0000e+00
# Epoch 9/100
# 74/74 [==============================] - 41s 560ms/step - accuracy: 0.4213 - student_loss: 1.7832 - distillation_loss: 1.6441 - val_accuracy: 0.4471 - val_student_loss: 1.7367 - val_distillation_loss: 0.0000e+00
# Epoch 10/100
# 74/74 [==============================] - 41s 560ms/step - accuracy: 0.4750 - student_loss: 1.6836 - distillation_loss: 1.5298 - val_accuracy: 0.4577 - val_student_loss: 1.7480 - val_distillation_loss: 0.0000e+00
# Epoch 11/100
# 74/74 [==============================] - 41s 560ms/step - accuracy: 0.5147 - student_loss: 1.5899 - distillation_loss: 1.4247 - val_accuracy: 0.5240 - val_student_loss: 1.5648 - val_distillation_loss: 0.0000e+00
# Epoch 12/100
# 74/74 [==============================] - 41s 560ms/step - accuracy: 0.5495 - student_loss: 1.5113 - distillation_loss: 1.3470 - val_accuracy: 0.5817 - val_student_loss: 1.4608 - val_distillation_loss: 0.0000e+00
# Epoch 13/100
# 74/74 [==============================] - 41s 560ms/step - accuracy: 0.6015 - student_loss: 1.4105 - distillation_loss: 1.2216 - val_accuracy: 0.6106 - val_student_loss: 1.3817 - val_distillation_loss: 0.0000e+00
# Epoch 14/100
# 74/74 [==============================] - 41s 560ms/step - accuracy: 0.6452 - student_loss: 1.3173 - distillation_loss: 1.1150 - val_accuracy: 0.6490 - val_student_loss: 1.3065 - val_distillation_loss: 0.0000e+00
# Epoch 15/100
# 74/74 [==============================] - 41s 560ms/step - accuracy: 0.6662 - student_loss: 1.2684 - distillation_loss: 1.0666 - val_accuracy: 0.6798 - val_student_loss: 1.2454 - val_distillation_loss: 0.0000e+00
# Epoch 16/100
# 74/74 [==============================] - 41s 560ms/step - accuracy: 0.6819 - student_loss: 1.2311 - distillation_loss: 1.0288 - val_accuracy: 0.6788 - val_student_loss: 1.2740 - val_distillation_loss: 0.0000e+00
# Epoch 17/100
# 74/74 [==============================] - 41s 560ms/step - accuracy: 0.7011 - student_loss: 1.1791 - distillation_loss: 0.9773 - val_accuracy: 0.6971 - val_student_loss: 1.2147 - val_distillation_loss: 0.0000e+00
# Epoch 18/100
# 74/74 [==============================] - 41s 561ms/step - accuracy: 0.7185 - student_loss: 1.1350 - distillation_loss: 0.9356 - val_accuracy: 0.6875 - val_student_loss: 1.1975 - val_distillation_loss: 0.0000e+00
# Epoch 19/100
# 74/74 [==============================] - 41s 560ms/step - accuracy: 0.7409 - student_loss: 1.0869 - distillation_loss: 0.8747 - val_accuracy: 0.7327 - val_student_loss: 1.1351 - val_distillation_loss: 0.0000e+00
# Epoch 20/100
# 74/74 [==============================] - 41s 560ms/step - accuracy: 0.7563 - student_loss: 1.0479 - distillation_loss: 0.8383 - val_accuracy: 0.7096 - val_student_loss: 1.1996 - val_distillation_loss: 0.0000e+00
# Epoch 21/100
# 74/74 [==============================] - 41s 560ms/step - accuracy: 0.7711 - student_loss: 1.0210 - distillation_loss: 0.8122 - val_accuracy: 0.7288 - val_student_loss: 1.1571 - val_distillation_loss: 0.0000e+00
# Epoch 22/100
# 74/74 [==============================] - 41s 560ms/step - accuracy: 0.7689 - student_loss: 1.0142 - distillation_loss: 0.8060 - val_accuracy: 0.7327 - val_student_loss: 1.1211 - val_distillation_loss: 0.0000e+00
# Epoch 23/100
# 74/74 [==============================] - 41s 559ms/step - accuracy: 0.7947 - student_loss: 0.9633 - distillation_loss: 0.7515 - val_accuracy: 0.7510 - val_student_loss: 1.1107 - val_distillation_loss: 0.0000e+00
# Epoch 24/100
# 74/74 [==============================] - 41s 560ms/step - accuracy: 0.8039 - student_loss: 0.9327 - distillation_loss: 0.7175 - val_accuracy: 0.7587 - val_student_loss: 1.0967 - val_distillation_loss: 0.0000e+00
# Epoch 25/100
# 74/74 [==============================] - 41s 560ms/step - accuracy: 0.8181 - student_loss: 0.9017 - distillation_loss: 0.6835 - val_accuracy: 0.7779 - val_student_loss: 1.0748 - val_distillation_loss: 0.0000e+00
# Epoch 26/100
# 74/74 [==============================] - 41s 560ms/step - accuracy: 0.8229 - student_loss: 0.8848 - distillation_loss: 0.6677 - val_accuracy: 0.7788 - val_student_loss: 1.0600 - val_distillation_loss: 0.0000e+00
# Epoch 27/100
# 74/74 [==============================] - 41s 560ms/step - accuracy: 0.8261 - student_loss: 0.8785 - distillation_loss: 0.6519 - val_accuracy: 0.7846 - val_student_loss: 1.0560 - val_distillation_loss: 0.0000e+00
# Epoch 28/100
# 74/74 [==============================] - 41s 560ms/step - accuracy: 0.8278 - student_loss: 0.8692 - distillation_loss: 0.6521 - val_accuracy: 0.7933 - val_student_loss: 1.0553 - val_distillation_loss: 0.0000e+00
# Epoch 29/100
# 74/74 [==============================] - 41s 559ms/step - accuracy: 0.8364 - student_loss: 0.8565 - distillation_loss: 0.6291 - val_accuracy: 0.7683 - val_student_loss: 1.0917 - val_distillation_loss: 0.0000e+00
# Epoch 30/100
# 74/74 [==============================] - 41s 560ms/step - accuracy: 0.8360 - student_loss: 0.8568 - distillation_loss: 0.6306 - val_accuracy: 0.7462 - val_student_loss: 1.0817 - val_distillation_loss: 0.0000e+00
# Epoch 31/100
# 74/74 [==============================] - 41s 560ms/step - accuracy: 0.8425 - student_loss: 0.8409 - distillation_loss: 0.6099 - val_accuracy: 0.7558 - val_student_loss: 1.1182 - val_distillation_loss: 0.0000e+00
# Epoch 32/100
# 74/74 [==============================] - 41s 560ms/step - accuracy: 0.8565 - student_loss: 0.8058 - distillation_loss: 0.5644 - val_accuracy: 0.7356 - val_student_loss: 1.1258 - val_distillation_loss: 0.0000e+00
# Epoch 33/100
# 74/74 [==============================] - 41s 560ms/step - accuracy: 0.8634 - student_loss: 0.7907 - distillation_loss: 0.5556 - val_accuracy: 0.7981 - val_student_loss: 1.0105 - val_distillation_loss: 0.0000e+00
# Epoch 34/100
# 74/74 [==============================] - 41s 560ms/step - accuracy: 0.8654 - student_loss: 0.7841 - distillation_loss: 0.5478 - val_accuracy: 0.7981 - val_student_loss: 1.0262 - val_distillation_loss: 0.0000e+00
# Epoch 35/100
# 74/74 [==============================] - 41s 560ms/step - accuracy: 0.8802 - student_loss: 0.7508 - distillation_loss: 0.5080 - val_accuracy: 0.8058 - val_student_loss: 0.9718 - val_distillation_loss: 0.0000e+00
# Epoch 36/100
# 74/74 [==============================] - 41s 559ms/step - accuracy: 0.8833 - student_loss: 0.7333 - distillation_loss: 0.4793 - val_accuracy: 0.8038 - val_student_loss: 0.9959 - val_distillation_loss: 0.0000e+00
# Epoch 37/100
# 74/74 [==============================] - 41s 560ms/step - accuracy: 0.8813 - student_loss: 0.7363 - distillation_loss: 0.4807 - val_accuracy: 0.7885 - val_student_loss: 1.0632 - val_distillation_loss: 0.0000e+00
# Epoch 38/100
# 74/74 [==============================] - 41s 560ms/step - accuracy: 0.8802 - student_loss: 0.7343 - distillation_loss: 0.4625 - val_accuracy: 0.7990 - val_student_loss: 1.0026 - val_distillation_loss: 0.0000e+00
# Epoch 39/100
# 74/74 [==============================] - 41s 560ms/step - accuracy: 0.8841 - student_loss: 0.7219 - distillation_loss: 0.4560 - val_accuracy: 0.7885 - val_student_loss: 1.0511 - val_distillation_loss: 0.0000e+00
# Epoch 40/100
# 74/74 [==============================] - 41s 559ms/step - accuracy: 0.8846 - student_loss: 0.7248 - distillation_loss: 0.4488 - val_accuracy: 0.7885 - val_student_loss: 1.0361 - val_distillation_loss: 0.0000e+00
# Epoch 41/100
# 74/74 [==============================] - 41s 561ms/step - accuracy: 0.8834 - student_loss: 0.7307 - distillation_loss: 0.4618 - val_accuracy: 0.7683 - val_student_loss: 1.1267 - val_distillation_loss: 0.0000e+00
# Epoch 42/100
# 74/74 [==============================] - 41s 560ms/step - accuracy: 0.8834 - student_loss: 0.7229 - distillation_loss: 0.4287 - val_accuracy: 0.8096 - val_student_loss: 1.0331 - val_distillation_loss: 0.0000e+00
# Epoch 43/100
# 74/74 [==============================] - 41s 560ms/step - accuracy: 0.8821 - student_loss: 0.7241 - distillation_loss: 0.4455 - val_accuracy: 0.8173 - val_student_loss: 1.0069 - val_distillation_loss: 0.0000e+00
# Epoch 44/100
# 74/74 [==============================] - 41s 560ms/step - accuracy: 0.8882 - student_loss: 0.7100 - distillation_loss: 0.4312 - val_accuracy: 0.7596 - val_student_loss: 1.1330 - val_distillation_loss: 0.0000e+00
# Epoch 45/100
# 74/74 [==============================] - 41s 561ms/step - accuracy: 0.8818 - student_loss: 0.7239 - distillation_loss: 0.4394 - val_accuracy: 0.7635 - val_student_loss: 1.1137 - val_distillation_loss: 0.0000e+00
# Epoch 46/100
# 74/74 [==============================] - 41s 561ms/step - accuracy: 0.8736 - student_loss: 0.7379 - distillation_loss: 0.4644 - val_accuracy: 0.7442 - val_student_loss: 1.1592 - val_distillation_loss: 0.0000e+00
# Epoch 47/100
# 74/74 [==============================] - 41s 560ms/step - accuracy: 0.8713 - student_loss: 0.7486 - distillation_loss: 0.4662 - val_accuracy: 0.7952 - val_student_loss: 1.0473 - val_distillation_loss: 0.0000e+00
# Epoch 48/100
# 74/74 [==============================] - 41s 560ms/step - accuracy: 0.8809 - student_loss: 0.7225 - distillation_loss: 0.4402 - val_accuracy: 0.7971 - val_student_loss: 1.0263 - val_distillation_loss: 0.0000e+00
# Epoch 49/100
# 74/74 [==============================] - 41s 560ms/step - accuracy: 0.8933 - student_loss: 0.6946 - distillation_loss: 0.4017 - val_accuracy: 0.8106 - val_student_loss: 0.9691 - val_distillation_loss: 0.0000e+00
# Epoch 50/100
# 74/74 [==============================] - 41s 560ms/step - accuracy: 0.8894 - student_loss: 0.6974 - distillation_loss: 0.4026 - val_accuracy: 0.7760 - val_student_loss: 1.1528 - val_distillation_loss: 0.0000e+00
# Epoch 51/100
# 74/74 [==============================] - 41s 560ms/step - accuracy: 0.8875 - student_loss: 0.7017 - distillation_loss: 0.4080 - val_accuracy: 0.8308 - val_student_loss: 0.9644 - val_distillation_loss: 0.0000e+00
# Epoch 52/100
# 74/74 [==============================] - 41s 561ms/step - accuracy: 0.8920 - student_loss: 0.6910 - distillation_loss: 0.3934 - val_accuracy: 0.8048 - val_student_loss: 1.0113 - val_distillation_loss: 0.0000e+00
# Epoch 53/100
# 74/74 [==============================] - 41s 560ms/step - accuracy: 0.8862 - student_loss: 0.7032 - distillation_loss: 0.3984 - val_accuracy: 0.7875 - val_student_loss: 1.0688 - val_distillation_loss: 0.0000e+00
# Epoch 54/100
# 74/74 [==============================] - 42s 561ms/step - accuracy: 0.8903 - student_loss: 0.6873 - distillation_loss: 0.3851 - val_accuracy: 0.8298 - val_student_loss: 0.9896 - val_distillation_loss: 0.0000e+00
# Epoch 55/100
# 74/74 [==============================] - 42s 561ms/step - accuracy: 0.8952 - student_loss: 0.6772 - distillation_loss: 0.3669 - val_accuracy: 0.8327 - val_student_loss: 0.9511 - val_distillation_loss: 0.0000e+00
# Epoch 56/100
# 74/74 [==============================] - 42s 561ms/step - accuracy: 0.8995 - student_loss: 0.6638 - distillation_loss: 0.3452 - val_accuracy: 0.8221 - val_student_loss: 0.9693 - val_distillation_loss: 0.0000e+00
# Epoch 57/100
# 74/74 [==============================] - 41s 561ms/step - accuracy: 0.8943 - student_loss: 0.6588 - distillation_loss: 0.3342 - val_accuracy: 0.8192 - val_student_loss: 0.9656 - val_distillation_loss: 0.0000e+00
# Epoch 58/100
# 74/74 [==============================] - 41s 561ms/step - accuracy: 0.8969 - student_loss: 0.6640 - distillation_loss: 0.3390 - val_accuracy: 0.8115 - val_student_loss: 0.9661 - val_distillation_loss: 0.0000e+00
# Epoch 59/100
# 74/74 [==============================] - 41s 560ms/step - accuracy: 0.8998 - student_loss: 0.6525 - distillation_loss: 0.3232 - val_accuracy: 0.8327 - val_student_loss: 0.9572 - val_distillation_loss: 0.0000e+00
# Epoch 60/100
# 74/74 [==============================] - 42s 561ms/step - accuracy: 0.9031 - student_loss: 0.6462 - distillation_loss: 0.3112 - val_accuracy: 0.8019 - val_student_loss: 1.0778 - val_distillation_loss: 0.0000e+00
# Epoch 61/100
# 74/74 [==============================] - 41s 560ms/step - accuracy: 0.8968 - student_loss: 0.6576 - distillation_loss: 0.3283 - val_accuracy: 0.8019 - val_student_loss: 1.0213 - val_distillation_loss: 0.0000e+00
# Epoch 62/100
# 74/74 [==============================] - 41s 560ms/step - accuracy: 0.8958 - student_loss: 0.6514 - distillation_loss: 0.3032 - val_accuracy: 0.8010 - val_student_loss: 1.0165 - val_distillation_loss: 0.0000e+00
# Epoch 63/100
# 74/74 [==============================] - 41s 560ms/step - accuracy: 0.8945 - student_loss: 0.6476 - distillation_loss: 0.2993 - val_accuracy: 0.8106 - val_student_loss: 0.9860 - val_distillation_loss: 0.0000e+00
# Epoch 64/100
# 55/74 [=====================>........] - ETA: 10s - accuracy: 0.8959 - student_loss: 0.6478 - distillation_loss: 0.2918

# %% [markdown]
# # Fine Tune BiT Model

# %%
MODULE_URL = "https://tfhub.dev/google/bit/m-r50x1/1"

BATCH_SIZE = 128
SZ = 224
NUM_EPOCHS = 100
steps_per_epoch= 9367//BATCH_SIZE
validation_steps= 1040//BATCH_SIZE
AUTO = tf.data.AUTOTUNE
NB_CLASSES = 10

# %%
# ## Creating data augmentation layer
augmentation_layer= keras.Sequential(
  [tf.keras.layers.RandomFlip('horizontal', seed= 42),
   tf.keras.layers.RandomFlip('vertical', seed= 42),
   tf.keras.layers.RandomRotation(0.2, fill_mode= 'wrap', seed= 42),
   tf.keras.layers.RandomZoom(0.2, seed= 42)]
   )

# %%
hub_module = hub.KerasLayer(MODULE_URL)

model = keras.Sequential(
    [
        keras.Input((SZ, SZ, 3)),
        augmentation_layer,
        keras.layers.Rescaling(scale=1.0 / 255),
        hub_module,
        keras.layers.Dense(NB_CLASSES, kernel_initializer="zeros"),
    ],
    name="bit_teacher_paddy_doctor",
)
print(f"Number of parameters (millions): {model.count_params() / 1e6}.")
# Out:
# Number of parameters (millions): 23.520842.

# %%
'''SCHEDULE_LENGTH = 500
SCHEDULE_LENGTH = SCHEDULE_LENGTH * 512 / BATCH_SIZE

SCHEDULE_BOUNDARIES = [200, 300, 400]
lr = 0.003 * BATCH_SIZE / 512

# Decay learning rate by a factor of 10 at SCHEDULE_BOUNDARIES.
lr_schedule = keras.optimizers.schedules.PiecewiseConstantDecay(
    boundaries=SCHEDULE_BOUNDARIES, values=[lr, lr * 0.1, lr * 0.001, lr * 0.0001]
)
optimizer = keras.optimizers.SGD(learning_rate=lr_schedule, momentum=0.9)

loss_fn = keras.losses.CategoricalCrossentropy(from_logits=True)'''

# %%
tf.__version__
# Out:
# '2.8.2'

# %%
# Fine Tuning m-r50x1 BiT model with Adam optimizer for 100 epochs

loss_fn = keras.losses.CategoricalCrossentropy(from_logits= True)
model.compile(optimizer= 'adam', loss=loss_fn, metrics=["accuracy"])

history1 = model.fit(train_data.repeat(),
    steps_per_epoch= steps_per_epoch,
    validation_steps= validation_steps,
    epochs=NUM_EPOCHS,
    validation_data=val_data
)
# Out:
# Epoch 1/100
# 73/73 [==============================] - 540s 6s/step - loss: 1.4230 - accuracy: 0.5176 - val_loss: 1.0983 - val_accuracy: 0.6279
# Epoch 2/100
# 73/73 [==============================] - 20s 273ms/step - loss: 1.0417 - accuracy: 0.6467 - val_loss: 0.9650 - val_accuracy: 0.6582
# Epoch 3/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.9393 - accuracy: 0.6829 - val_loss: 0.9107 - val_accuracy: 0.6836
# Epoch 4/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.8754 - accuracy: 0.7041 - val_loss: 0.7980 - val_accuracy: 0.7080
# Epoch 5/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.8407 - accuracy: 0.7113 - val_loss: 0.8837 - val_accuracy: 0.6748
# Epoch 6/100
# 73/73 [==============================] - 20s 271ms/step - loss: 0.7893 - accuracy: 0.7349 - val_loss: 0.8754 - val_accuracy: 0.6621
# Epoch 7/100
# 73/73 [==============================] - 20s 271ms/step - loss: 0.7570 - accuracy: 0.7416 - val_loss: 0.8386 - val_accuracy: 0.7041
# Epoch 8/100
# 73/73 [==============================] - 20s 271ms/step - loss: 0.7521 - accuracy: 0.7441 - val_loss: 0.8013 - val_accuracy: 0.7197
# Epoch 9/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.7254 - accuracy: 0.7573 - val_loss: 0.8008 - val_accuracy: 0.6963
# Epoch 10/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.7160 - accuracy: 0.7634 - val_loss: 0.7643 - val_accuracy: 0.7178
# Epoch 11/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.7040 - accuracy: 0.7629 - val_loss: 0.7427 - val_accuracy: 0.7334
# Epoch 12/100
# 73/73 [==============================] - 20s 269ms/step - loss: 0.6793 - accuracy: 0.7675 - val_loss: 0.6867 - val_accuracy: 0.7559
# Epoch 13/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.6619 - accuracy: 0.7790 - val_loss: 0.7715 - val_accuracy: 0.7412
# Epoch 14/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.6643 - accuracy: 0.7729 - val_loss: 0.6824 - val_accuracy: 0.7666
# Epoch 15/100
# 73/73 [==============================] - 20s 269ms/step - loss: 0.6391 - accuracy: 0.7896 - val_loss: 0.6809 - val_accuracy: 0.7676
# Epoch 16/100
# 73/73 [==============================] - 20s 269ms/step - loss: 0.6283 - accuracy: 0.7910 - val_loss: 0.6478 - val_accuracy: 0.7656
# Epoch 17/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.6346 - accuracy: 0.7829 - val_loss: 0.6606 - val_accuracy: 0.7646
# Epoch 18/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.6278 - accuracy: 0.7855 - val_loss: 0.7114 - val_accuracy: 0.7490
# Epoch 19/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.6050 - accuracy: 0.7942 - val_loss: 0.6751 - val_accuracy: 0.7500
# Epoch 20/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.6114 - accuracy: 0.7962 - val_loss: 0.7001 - val_accuracy: 0.7412
# Epoch 21/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.6133 - accuracy: 0.7879 - val_loss: 0.7296 - val_accuracy: 0.7363
# Epoch 22/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.5874 - accuracy: 0.8000 - val_loss: 0.6784 - val_accuracy: 0.7559
# Epoch 23/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.5970 - accuracy: 0.8001 - val_loss: 0.6685 - val_accuracy: 0.7637
# Epoch 24/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.5990 - accuracy: 0.7939 - val_loss: 0.6928 - val_accuracy: 0.7627
# Epoch 25/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.5795 - accuracy: 0.8004 - val_loss: 0.6333 - val_accuracy: 0.7783
# Epoch 26/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.5850 - accuracy: 0.8015 - val_loss: 0.6672 - val_accuracy: 0.7725
# Epoch 27/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.5655 - accuracy: 0.8054 - val_loss: 0.6424 - val_accuracy: 0.7783
# Epoch 28/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.5647 - accuracy: 0.8076 - val_loss: 0.6824 - val_accuracy: 0.7568
# Epoch 29/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.5557 - accuracy: 0.8067 - val_loss: 0.6348 - val_accuracy: 0.7744
# Epoch 30/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.5479 - accuracy: 0.8093 - val_loss: 0.6728 - val_accuracy: 0.7588
# Epoch 31/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.5563 - accuracy: 0.8053 - val_loss: 0.7503 - val_accuracy: 0.7549
# Epoch 32/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.5575 - accuracy: 0.8085 - val_loss: 0.6458 - val_accuracy: 0.7852
# Epoch 33/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.5409 - accuracy: 0.8187 - val_loss: 0.6352 - val_accuracy: 0.7891
# Epoch 34/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.5504 - accuracy: 0.8112 - val_loss: 0.6482 - val_accuracy: 0.7695
# Epoch 35/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.5457 - accuracy: 0.8169 - val_loss: 0.6649 - val_accuracy: 0.7627
# Epoch 36/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.5398 - accuracy: 0.8184 - val_loss: 0.6429 - val_accuracy: 0.7822
# Epoch 37/100
# 73/73 [==============================] - 20s 269ms/step - loss: 0.5293 - accuracy: 0.8196 - val_loss: 0.6516 - val_accuracy: 0.7793
# Epoch 38/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.5325 - accuracy: 0.8232 - val_loss: 0.6233 - val_accuracy: 0.7666
# Epoch 39/100
# 73/73 [==============================] - 20s 269ms/step - loss: 0.5391 - accuracy: 0.8135 - val_loss: 0.6872 - val_accuracy: 0.7480
# Epoch 40/100
# 73/73 [==============================] - 20s 269ms/step - loss: 0.5293 - accuracy: 0.8212 - val_loss: 0.7204 - val_accuracy: 0.7510
# Epoch 41/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.5230 - accuracy: 0.8195 - val_loss: 0.7479 - val_accuracy: 0.7295
# Epoch 42/100
# 73/73 [==============================] - 20s 269ms/step - loss: 0.5349 - accuracy: 0.8156 - val_loss: 0.7644 - val_accuracy: 0.7402
# Epoch 43/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.5280 - accuracy: 0.8256 - val_loss: 0.6351 - val_accuracy: 0.7676
# Epoch 44/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.5259 - accuracy: 0.8192 - val_loss: 0.5956 - val_accuracy: 0.7891
# Epoch 45/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.5201 - accuracy: 0.8216 - val_loss: 0.6662 - val_accuracy: 0.7783
# Epoch 46/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.5184 - accuracy: 0.8267 - val_loss: 0.5991 - val_accuracy: 0.7793
# Epoch 47/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.5233 - accuracy: 0.8218 - val_loss: 0.6817 - val_accuracy: 0.7598
# Epoch 48/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.5209 - accuracy: 0.8187 - val_loss: 0.6634 - val_accuracy: 0.7715
# Epoch 49/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.5197 - accuracy: 0.8235 - val_loss: 0.6665 - val_accuracy: 0.7764
# Epoch 50/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.5155 - accuracy: 0.8265 - val_loss: 0.7990 - val_accuracy: 0.7344
# Epoch 51/100
# 73/73 [==============================] - 20s 269ms/step - loss: 0.5080 - accuracy: 0.8258 - val_loss: 0.7614 - val_accuracy: 0.7480
# Epoch 52/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.5251 - accuracy: 0.8203 - val_loss: 0.7068 - val_accuracy: 0.7510
# Epoch 53/100
# 73/73 [==============================] - 20s 269ms/step - loss: 0.5132 - accuracy: 0.8228 - val_loss: 0.8145 - val_accuracy: 0.7354
# Epoch 54/100
# 73/73 [==============================] - 20s 269ms/step - loss: 0.5253 - accuracy: 0.8209 - val_loss: 0.6429 - val_accuracy: 0.7920
# Epoch 55/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.4876 - accuracy: 0.8313 - val_loss: 0.6334 - val_accuracy: 0.7715
# Epoch 56/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.5215 - accuracy: 0.8202 - val_loss: 0.6785 - val_accuracy: 0.7617
# Epoch 57/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.4983 - accuracy: 0.8309 - val_loss: 0.6576 - val_accuracy: 0.7656
# Epoch 58/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.5042 - accuracy: 0.8286 - val_loss: 0.7435 - val_accuracy: 0.7373
# Epoch 59/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.5011 - accuracy: 0.8326 - val_loss: 0.6446 - val_accuracy: 0.7715
# Epoch 60/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.4799 - accuracy: 0.8333 - val_loss: 0.6432 - val_accuracy: 0.7676
# Epoch 61/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.5166 - accuracy: 0.8230 - val_loss: 0.6410 - val_accuracy: 0.7871
# Epoch 62/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.5139 - accuracy: 0.8247 - val_loss: 0.6169 - val_accuracy: 0.7871
# Epoch 63/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.5202 - accuracy: 0.8220 - val_loss: 0.6625 - val_accuracy: 0.7822
# Epoch 64/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.4850 - accuracy: 0.8387 - val_loss: 0.6761 - val_accuracy: 0.7891
# Epoch 65/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.4784 - accuracy: 0.8334 - val_loss: 0.7545 - val_accuracy: 0.7607
# Epoch 66/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.4810 - accuracy: 0.8409 - val_loss: 0.8459 - val_accuracy: 0.7285
# Epoch 67/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.4940 - accuracy: 0.8348 - val_loss: 0.6539 - val_accuracy: 0.7793
# Epoch 68/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.4914 - accuracy: 0.8295 - val_loss: 0.6752 - val_accuracy: 0.7773
# Epoch 69/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.4975 - accuracy: 0.8300 - val_loss: 0.6867 - val_accuracy: 0.7637
# Epoch 70/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.5030 - accuracy: 0.8326 - val_loss: 0.6475 - val_accuracy: 0.7852
# Epoch 71/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.4807 - accuracy: 0.8343 - val_loss: 0.5869 - val_accuracy: 0.8008
# Epoch 72/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.4737 - accuracy: 0.8331 - val_loss: 0.6493 - val_accuracy: 0.7861
# Epoch 73/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.4908 - accuracy: 0.8307 - val_loss: 0.6049 - val_accuracy: 0.7979
# Epoch 74/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.4744 - accuracy: 0.8389 - val_loss: 0.6854 - val_accuracy: 0.7666
# Epoch 75/100
# 73/73 [==============================] - 20s 272ms/step - loss: 0.4925 - accuracy: 0.8317 - val_loss: 0.6797 - val_accuracy: 0.7695
# Epoch 76/100
# 73/73 [==============================] - 20s 272ms/step - loss: 0.4705 - accuracy: 0.8372 - val_loss: 0.7278 - val_accuracy: 0.7471
# Epoch 77/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.4650 - accuracy: 0.8401 - val_loss: 0.6042 - val_accuracy: 0.7959
# Epoch 78/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.4831 - accuracy: 0.8307 - val_loss: 0.5799 - val_accuracy: 0.8037
# Epoch 79/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.4755 - accuracy: 0.8425 - val_loss: 0.6210 - val_accuracy: 0.7900
# Epoch 80/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.4682 - accuracy: 0.8422 - val_loss: 0.6292 - val_accuracy: 0.7744
# Epoch 81/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.4854 - accuracy: 0.8327 - val_loss: 0.6199 - val_accuracy: 0.7900
# Epoch 82/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.4749 - accuracy: 0.8356 - val_loss: 0.6603 - val_accuracy: 0.7744
# Epoch 83/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.4710 - accuracy: 0.8424 - val_loss: 0.6066 - val_accuracy: 0.7812
# Epoch 84/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.4796 - accuracy: 0.8386 - val_loss: 0.6003 - val_accuracy: 0.7910
# Epoch 85/100
# 73/73 [==============================] - 20s 269ms/step - loss: 0.4539 - accuracy: 0.8448 - val_loss: 0.5835 - val_accuracy: 0.7998
# Epoch 86/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.4619 - accuracy: 0.8406 - val_loss: 0.6638 - val_accuracy: 0.7715
# Epoch 87/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.4882 - accuracy: 0.8360 - val_loss: 0.6936 - val_accuracy: 0.7656
# Epoch 88/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.4569 - accuracy: 0.8448 - val_loss: 0.6087 - val_accuracy: 0.7900
# Epoch 89/100
# 73/73 [==============================] - 20s 269ms/step - loss: 0.4779 - accuracy: 0.8398 - val_loss: 0.6896 - val_accuracy: 0.7646
# Epoch 90/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.4604 - accuracy: 0.8459 - val_loss: 0.5933 - val_accuracy: 0.7979
# Epoch 91/100
# 73/73 [==============================] - 20s 269ms/step - loss: 0.4833 - accuracy: 0.8373 - val_loss: 0.5977 - val_accuracy: 0.7949
# Epoch 92/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.4771 - accuracy: 0.8342 - val_loss: 0.6447 - val_accuracy: 0.7773
# Epoch 93/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.4590 - accuracy: 0.8426 - val_loss: 0.6474 - val_accuracy: 0.7686
# Epoch 94/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.4623 - accuracy: 0.8432 - val_loss: 0.6357 - val_accuracy: 0.7744
# Epoch 95/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.4588 - accuracy: 0.8472 - val_loss: 0.6062 - val_accuracy: 0.7949
# Epoch 96/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.4757 - accuracy: 0.8366 - val_loss: 0.6234 - val_accuracy: 0.7891
# Epoch 97/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.4539 - accuracy: 0.8453 - val_loss: 0.6275 - val_accuracy: 0.7842
# Epoch 98/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.4741 - accuracy: 0.8359 - val_loss: 0.5596 - val_accuracy: 0.8066
# Epoch 99/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.4481 - accuracy: 0.8452 - val_loss: 0.5810 - val_accuracy: 0.7871
# Epoch 100/100
# 73/73 [==============================] - 20s 270ms/step - loss: 0.4683 - accuracy: 0.8406 - val_loss: 0.6100 - val_accuracy: 0.7959

# %%
model.save("/content/drive/MyDrive/thesis/dataset/paddy_doctor/bit_teacher_paddy_doctor2")
# Out:
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/thesis/dataset/paddy_doctor/bit_teacher_paddy_doctor2/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/thesis/dataset/paddy_doctor/bit_teacher_paddy_doctor2/assets

# %%
'''
model.compile(loss=tf.keras.losses.CategoricalCrossentropy(), optimizer=tf.keras.optimizers.Adam(learning_rate=0.00001), metrics=['accuracy'])
callback2=tf.keras.callbacks.EarlyStopping(monitor='accuracy', patience=3, restore_best_weights=True)
history_tuned=model.fit(train_data, validation_data=val_data, epochs=40, initial_epoch=history.epoch[-1], callbacks=[callback2] )
